# %% [markdown]
# # Sentiments towards COVID-19 Vaccine in South Africa

# %% [markdown]
# ## Background
# What were we trying to achieve? What are the key results/insights did we obtain? How did we get to these insights? What data was used and how was it processed?

# %%
# !pip install stop-words
# Out:
# Collecting stop-words
#   Downloading https://files.pythonhosted.org/packages/1c/cb/d58290804b7a4c5daa42abbbe2a93c477ae53e45541b1825e86f0dfaaf63/stop-words-2018.7.23.tar.gz
# Building wheels for collected packages: stop-words
#   Running setup.py bdist_wheel for stop-words ... error
#   Complete output from command /home/felix/Documents/Environments/prob_programming/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-wl437via/stop-words/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/pip-wheel-vup60yip --python-tag cp37:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for stop-words
#   Running setup.py clean for stop-words
# Failed to build stop-words
# Installing collected packages: stop-words
#   Running setup.py install for stop-words ... done
# Successfully installed stop-words-2018.7.23

# %%
# Importing useful packages
import pandas as pd
import numpy as np
import nltk
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize 
from stop_words import get_stop_words
import re
from english_words import english_words_set
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
#nltk.download(Stopwords)

# %% [markdown]
# ## Data preprocessing

# %%
# Data imports
df1 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = 'QnGqQx-EA4g')
df2 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = '0jejyuRQLxc')
df3 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = 'gklQh5v0UuI')
df4 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = 'mcPzF-GSoiY')
df5 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = 'Q66BMCJMeHY')
df6 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = '-HLZwv_Eh7w')
df7 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = 'VwZFkMlUQGs')
df8 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = 'fCgbUyxXhAM')
df9 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = 'Fs1bel0HM6Y')
df10 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = '09PASKB3sgU')
df11 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = 'HfN1oPBGXRk')
df12 = pd.read_excel('Covid_vaccine_sentiments.xlsx',sheet_name = 'E3lSVH64u9k')

# %%
df1.shape[0] + df2.shape[0] + df3.shape[0] + df4.shape[0] + df5.shape[0] + df6.shape[0] + df7.shape[0] + df8.shape[0] + df9.shape[0] + df10.shape[0] + df11.shape[0] + df12.shape[0]
# Out:
# 2757

# %%
df1.columns
# Out:
# Index(['Name', 'Comment', 'Time', 'Likes', 'Reply Count', 'Reply Author',
#        'Reply', 'Published', 'Updated'],
#       dtype='object')

# %%
#Combining into one main data frame. # Comments without replies from all videos
frames_comments = [df1[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                        df2[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                        df3[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                        df4[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                        df5[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                        df6[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']], 
                        df7[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                        df8[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                        df9[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                        df10[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                        df11[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']],
                       df12[['Name', 'Comment', 'Time', 'Likes', 'Reply Count']]]
comments  = pd.concat(frames_comments).dropna().reset_index()

# %%
#Combining into one main data frame. # Comments without replies from all videos
frames_replies = [df1[['Reply Author','Reply', 'Published', 'Updated']],
                        df2[['Reply Author','Reply', 'Published', 'Updated']],
                        df3[['Reply Author','Reply', 'Published', 'Updated']],
                        df4[['Reply Author','Reply', 'Published', 'Updated']],
                        df5[['Reply Author','Reply', 'Published', 'Updated']],
                        df6[['Reply Author','Reply', 'Published', 'Updated']], 
                        df7[['Reply Author','Reply', 'Published', 'Updated']],
                        df8[['Reply Author','Reply', 'Published', 'Updated']],
                        df9[['Reply Author','Reply', 'Published', 'Updated']],
                        df10[['Reply Author','Reply', 'Published', 'Updated']],
                        df11[['Reply Author','Reply', 'Published', 'Updated']],
                        df12[['Reply Author','Reply', 'Published', 'Updated']]]
replies_to_comments = pd.concat(frames_replies).dropna().reset_index()

# %%
# Removing url
replies_cleaned = [re.sub(r'^https?:\/\/.*[\r\n]*', '', replies_to_comments['Reply'].iloc[i], flags=re.MULTILINE) for i in range(len(replies_to_comments))]
comments_cleaned = [re.sub(r'^https?:\/\/.*[\r\n]*', '', comments['Comment'].iloc[i], flags=re.MULTILINE) for i in range(len(comments))]

# %%
#Removing html
replies_cleaned = [re.sub(r'<[^<]+?>', '', replies_cleaned[i], flags=re.MULTILINE) for i in range(len(replies_cleaned))]
comments_cleaned = [re.sub(r'<[^<]+?>', '', comments_cleaned[i], flags=re.MULTILINE) for i in range(len(comments_cleaned))]

# %%
# Removing special characters
replies_cleaned = [re.sub(r'[^A-Za-z0-9]+', ' ', replies_cleaned[i], flags=re.MULTILINE) for i in range(len(replies_cleaned))]
comments_cleaned = [re.sub(r'[^A-Za-z0-9]+', ' ', comments_cleaned[i], flags=re.MULTILINE) for i in range(len(comments_cleaned))]

# %%
#Tokenizing
reply_tokens = [re.findall("\w+", replies_cleaned[i].lower()) for i in range(len(replies_cleaned))]
comment_tokens = [re.findall("\w+", comments_cleaned[i].lower()) for i in range(len(comments_cleaned))]

# %%
# Returning proper english words only
def going_english(sentences):
    """Input
       sentences: A list containing lists of tokenized sentences
       Output
       english_tokens: A list containing lists of tokenized sentences with english words only
    """
    english_tokens = []
    for i in range(len(sentences)):
        eng_wrds = []
        for word in sentences[i]:
            if word in english_words_set: # comparing with the imported english words
                eng_wrds.append(word)
        english_tokens.append(eng_wrds)
    return english_tokens

# %%
english_reply_tokens = going_english(reply_tokens)
english_comment_tokens = going_english(comment_tokens)

# %%
#english_comment_tokens

# %%
# Returning proper english words only
def remove_stopwords(sentences):
    """Input
       sentences: A list containing lists of tokenized sentences
       Output
       english_tokens: A list containing lists of tokenized sentences without english stopwords only
    """
    stop_words = get_stop_words('english')
    no_stopwords = []
    for i in range(len(sentences)):
        not_stopword = []
        for word in sentences[i]:
            if word not in stop_words: # comparing with the imported list of stopwords
                not_stopword.append(word)
        no_stopwords.append(not_stopword)
    return no_stopwords

# %%
cleaned_reply_tokens = remove_stopwords(english_reply_tokens)
cleaned_comment_tokens = remove_stopwords(english_comment_tokens)

# %%
cleaned_reply_tokens
# Out:
# [['stupid', 'best'],
#  ['trial', 'place', 'us', 're', 'rubbish'],
#  ['least', 'rubbish', 're', 'garbage', 'say', 'certainty', 'south'],
#  ['certain', 'vaccine', 'quality', 'quantity', 'material'],
#  ['hell',
#   'know',
#   'know',
#   's',
#   'voluntary',
#   'one',
#   'people',
#   'will',
#   'trust',
#   's',
#   'different'],
#  ['cause', 'road', 'agree'],
#  ['start', 'greedy'],
#  ['people',
#   'one',
#   'one',
#   'people',
#   'problem',
#   's',
#   'case',
#   'get',
#   'world',
#   'people'],
#  ['sister',
#   'right',
#   'congratulate',
#   'south',
#   'conduct',
#   'first',
#   'although',
#   'prefer',
#   'independent',
#   'run',
#   'nevertheless',
#   'know',
#   'will',
#   'stay',
#   'long',
#   'haul',
#   'even',
#   'will',
#   'long',
#   'damage',
#   'prevention',
#   'way',
#   'cure',
#   'let',
#   'alone',
#   'ignore',
#   'conspiracy',
#   'theory',
#   'accept'],
#  ['look', 'can', 'find', 'lung', 'tissue', 'video'],
#  ['s', 'straight', 'foundation'],
#  ['use', 'famous', 'people', 'pandemic', 'real'],
#  ['s', 'freedom', 'choice', 'volunteer', 'nobody', 'anyone', 'will'],
#  ['brother',
#   'even',
#   'test',
#   'take',
#   'vaccine',
#   'alter',
#   'genetic',
#   'material'],
#  ['will', 'search', 'info'],
#  ['right',
#   'point',
#   'except',
#   'say',
#   'imbalance',
#   'imbalance',
#   'nature',
#   'never',
#   'never',
#   'time',
#   'planet',
#   'nature',
#   'planet',
#   's',
#   'women',
#   'children',
#   'help',
#   'fact',
#   'women',
#   'children',
#   'know',
#   'live'],
#  ['s'],
#  ['controlling',
#   'media',
#   'strike',
#   'fear',
#   'people',
#   'corona',
#   'virus',
#   'fake'],
#  ['fake'],
#  [],
#  ['watch', 'channel'],
#  ['re', 'mad'],
#  ['fake',
#   'u',
#   'doctor',
#   'even',
#   'fake',
#   'people',
#   'got',
#   'virus',
#   'south',
#   'entire',
#   'world',
#   'act',
#   'movie'],
#  ['sake', 'think', 'south', 'chip', 'etc', 'whole', 'new', 'level'],
#  ['put',
#   'perspective',
#   'body',
#   'made',
#   'upon',
#   'bacteria',
#   'harm',
#   'never',
#   'harm',
#   'scientific',
#   'model',
#   'germ',
#   'theory',
#   'hoax',
#   'powerful',
#   'media',
#   'control',
#   'process',
#   'point',
#   'many',
#   'now',
#   'able',
#   'think',
#   'put',
#   'fear',
#   'global',
#   'much',
#   'logic',
#   'goes',
#   'window',
#   'fact',
#   'cure',
#   'virus',
#   'risk',
#   'virus',
#   'world',
#   's',
#   'lying',
#   'case',
#   'body',
#   'already',
#   'without',
#   'us',
#   'body',
#   'fantastic',
#   'machine',
#   'want',
#   'us',
#   'believe',
#   'able',
#   'survive',
#   'without',
#   'think',
#   'able',
#   'survive',
#   'planet',
#   'able',
#   'adapt',
#   'different',
#   'able',
#   'deal',
#   'virus',
#   'enemy',
#   's',
#   'continue',
#   'play',
#   'mind'],
#  [],
#  [],
#  ['thank'],
#  ['correct'],
#  ['thank', 'us', 'appreciate', 'south'],
#  [],
#  ['smart'],
#  ['thing',
#   'fight',
#   'evil',
#   'hate',
#   'self',
#   'ready',
#   'face',
#   'demonic',
#   'evil'],
#  ['wrath', 'man', 'produce', 'god', 'away', 'gun'],
#  [],
#  ['us', 'love', 'money', 'people', 'now', 'seeing'],
#  [],
#  ['papa', 'just', 'back', 'virus', 'take'],
#  ['good', 'right'],
#  ['know',
#   'history',
#   'western',
#   'world',
#   'certain',
#   'like',
#   'know',
#   'significant',
#   'women',
#   'able',
#   'children',
#   'insidious',
#   'western',
#   'across',
#   'don',
#   't',
#   'need',
#   'look',
#   'hard',
#   'information',
#   'talk',
#   'stop',
#   'quit',
#   'every',
#   'event',
#   'think',
#   'need',
#   'stop',
#   'stop',
#   'agenda',
#   'west'],
#  ['now', 'south', 'south'],
#  ['vaccine', 'fake', 'ass', 'virus'],
#  ['check',
#   'post',
#   'despicable',
#   'fact',
#   'just',
#   'one',
#   'many',
#   'lead',
#   'slaughter',
#   'media'],
#  ['go',
#   'life',
#   'hard',
#   'time',
#   'see',
#   'movie',
#   't',
#   'care',
#   'less',
#   'science',
#   'public',
#   'call',
#   'want',
#   't',
#   'mean',
#   'can',
#   'walk',
#   'water',
#   'name',
#   'mean',
#   'anyone',
#   'water',
#   'dusty',
#   'old',
#   'book',
#   'get',
#   'life'],
#  [],
#  ['left', 'us', 'rule', 'world', 'let', 'evil', 'greedy', 'take'],
#  ['can',
#   't',
#   'blame',
#   'god',
#   's',
#   'time',
#   'invite',
#   'back',
#   'nation',
#   'rid',
#   'evil',
#   's',
#   'still',
#   'time'],
#  ['k',
#   's',
#   'time',
#   'went',
#   'back',
#   'seek',
#   'ancient',
#   'spiritual',
#   'instead',
#   'accept',
#   'fed',
#   'enemy',
#   'don',
#   't',
#   'ounce',
#   'want',
#   'create',
#   'vaccine',
#   'destroy',
#   'indigenous',
#   'planet',
#   'can',
#   'claim',
#   'inheritance',
#   'testament',
#   'level',
#   'evil',
#   'will',
#   'commit',
#   'control',
#   'world'],
#  [],
#  ['sold'],
#  ['love'],
#  ['vaccine', 'order', 'immune', 'something', 'get'],
#  ['t', 's', 'point'],
#  ['ambassador', 'point', 'everyone', 'will'],
#  ['don',
#   't',
#   'think',
#   'just',
#   'like',
#   'will',
#   'vaccine',
#   'black',
#   'people',
#   'vaccine',
#   'something',
#   'similar',
#   'flu',
#   'threat',
#   'anyone',
#   't',
#   'black',
#   'will',
#   'make',
#   'everyone',
#   'hate',
#   'us'],
#  ['die', 'cause'],
#  ['just',
#   'another',
#   'sheep',
#   'media',
#   'wake',
#   'already',
#   'vaccine',
#   'china',
#   'south',
#   'well',
#   'sure',
#   'now',
#   'think',
#   'even',
#   'south',
#   'without',
#   'doubt',
#   'white',
#   'well',
#   'stop',
#   'cool',
#   'aid'],
#  [],
#  ['volunteer',
#   'take',
#   'vaccine',
#   'advocate',
#   'bet',
#   'bill',
#   't',
#   'take',
#   'say',
#   'without',
#   'doubt',
#   's',
#   'white',
#   'south',
#   'get',
#   'information',
#   'people',
#   'seen',
#   'black',
#   'can',
#   't',
#   'forget',
#   'done',
#   'past',
#   'central',
#   'false',
#   'hope'],
#  ['s',
#   'vaccine',
#   'now',
#   'done',
#   'volunteer',
#   'china',
#   'know',
#   'u',
#   's',
#   'central',
#   'half',
#   'century',
#   'ago',
#   'well',
#   'take',
#   'vaccine',
#   'today',
#   'black',
#   'don',
#   't',
#   'wish',
#   'participate',
#   'fine',
#   'absurd',
#   'think',
#   'case',
#   'numerous',
#   'step',
#   'original',
#   'point',
#   'fact',
#   'media',
#   'everything',
#   'took',
#   'huge',
#   'step',
#   'make',
#   'look',
#   'south',
#   'first',
#   'participate',
#   'deception',
#   'someday',
#   'hope',
#   'will',
#   'wake'],
#  ['know', 're', 'white'],
#  ['lot', 'faith', 'good', 'luck'],
#  ['also', 'well'],
#  ['correct',
#   'media',
#   'let',
#   's',
#   'use',
#   'common',
#   'sense',
#   'choose',
#   'best',
#   'option',
#   'think',
#   'will',
#   'benefit',
#   'us',
#   'will',
#   'never',
#   'take',
#   'vaccine'],
#  ['afford',
#   'well',
#   'kind',
#   'question',
#   'china',
#   'well',
#   'oh',
#   'meant',
#   'well',
#   'context',
#   'vaccine',
#   't',
#   'even',
#   'month',
#   'm',
#   'sure',
#   'won',
#   't',
#   'need',
#   'many',
#   'give',
#   'little',
#   'time',
#   'odd',
#   'question',
#   'indeed'],
#  ['black', 'small', 'chose', 'cheap', 'easy', 'need', 'wake', 'stop', 'big'],
#  ['stupid', 'comment'],
#  ['jimmy',
#   'fan',
#   'know',
#   'else',
#   'stupid',
#   'fact',
#   'bill',
#   'woman',
#   'come',
#   'poor',
#   'give',
#   'illusion',
#   're',
#   'help',
#   'people',
#   're',
#   'lab',
#   'think',
#   's',
#   'conspiracy',
#   'explain',
#   'central',
#   'south',
#   'white',
#   'went',
#   'people',
#   'made',
#   'spread',
#   'around'],
#  ['agree'],
#  ['foundation', 'follow', 'money'],
#  ['girl',
#   'amp',
#   's',
#   'glen',
#   'court',
#   'case',
#   'stolen',
#   'genetic',
#   'patient',
#   'month',
#   's',
#   'far',
#   'illegal'],
#  ['now', 'know', 'never', 'forget', 's'],
#  ['good', 'question'],
#  ['china',
#   'just',
#   'haven',
#   't',
#   'attention',
#   't',
#   'mean',
#   't',
#   'world',
#   'different'],
#  ['sell'],
#  ['volunteer', 'nobody', 'take'],
#  ['snow', 'grass', 't', 'china'],
#  ['t', 'think', 'whole', 'different', 'level'],
#  ['bill',
#   'smelly',
#   'everywhere',
#   'put',
#   'first',
#   'must',
#   'power',
#   'say',
#   'can',
#   'waste',
#   'money',
#   'people',
#   'need'],
#  ['start', 'china'],
#  ['mercy',
#   'grace',
#   'hi',
#   'great',
#   'service',
#   'video',
#   'content',
#   'information',
#   'vaccine'],
#  ['people',
#   'possible',
#   'good',
#   'read',
#   'another',
#   'book',
#   'just',
#   'one',
#   'stole',
#   'hotel'],
#  ['right',
#   'vaccine',
#   'don',
#   't',
#   'virus',
#   'don',
#   't',
#   'late',
#   'make',
#   'sure',
#   'head',
#   'line'],
#  ['s', 'done', 'money', 'sa', 'love', 'money', 'don', 't', 'care', 'people'],
#  ['journey',
#   'man',
#   'virus',
#   'percent',
#   'rate',
#   'afraid',
#   'bud',
#   'open',
#   'want',
#   'type',
#   'four',
#   'digit',
#   'three',
#   'digit',
#   'may',
#   'think',
#   'type',
#   'new',
#   'will',
#   'see',
#   'mate'],
#  [],
#  ['journey', 'man', 'want', 'remedy', 'vaccine'],
#  ['henry',
#   'let',
#   's',
#   'watch',
#   'n',
#   'see',
#   'happen',
#   'force',
#   'vaccine',
#   'us',
#   'us',
#   't',
#   'listen',
#   'us',
#   'will',
#   'toy',
#   'toy',
#   'will',
#   'operate',
#   'well',
#   't',
#   'take',
#   'anyone'],
#  ['seem', 's', 's', 'good'],
#  ['vaccine', 'truly', 'safety', 'know', 'work', 'industry'],
#  ['common', 'cold', 'different', 'etc', 'different'],
#  ['s', 'magic', 'science', 'also', 'think', 'fly', 'magic', 'right'],
#  ['s', 'will', 'one', 'become', 'less', 'experiment', 'south'],
#  ['sad', 'sold'],
#  ['glad', 't', 'attitude', 'polio', 'world'],
#  ['future', 'commentary', 'virus', 'vaccine'],
#  ['let',
#   'think',
#   'change',
#   'mind',
#   'comment',
#   'trust',
#   'say',
#   's',
#   'possible',
#   'dilemma'],
#  ['plan', 'enzyme', 'please', 'advise'],
#  ['god', 'gene'],
#  ['check', 'make', 'fool', 'already', 'china'],
#  ['re',
#   'valid',
#   'comment',
#   'point',
#   'low',
#   'world',
#   'test',
#   'period',
#   'given',
#   'history',
#   'use',
#   'harm',
#   'people',
#   'stop',
#   'don',
#   't',
#   'need',
#   'stoop',
#   'low',
#   'make',
#   'factual',
#   'comment',
#   'piss'],
#  ['agree', 'don', 't', 'quite', 'see'],
#  ['china', 'world', 'just'],
#  ['shame',
#   'president',
#   'shame',
#   'shame',
#   'shame',
#   'god',
#   'will',
#   'deal',
#   'done',
#   'south'],
#  ['think', 'earth', 'flat'],
#  ['ambassador', 'hoax'],
#  ['good', 'care', 'social', 'charge'],
#  ['absolute', 'truth'],
#  ['g',
#   'tell',
#   'sure',
#   'real',
#   'thing',
#   'cause',
#   'cause',
#   'said',
#   'oh',
#   'death',
#   'toll',
#   'calculate',
#   'day',
#   'virus',
#   'bird',
#   'flu',
#   'swine',
#   'flu',
#   'world',
#   'virus',
#   'even',
#   'admitting',
#   'everyone',
#   'death',
#   'people',
#   'like',
#   'don',
#   't',
#   'blink',
#   'eye',
#   'person',
#   'car',
#   'accident',
#   'test',
#   'back',
#   'positive',
#   'cause',
#   'death',
#   'now',
#   't',
#   'virus',
#   'may',
#   'fact',
#   'virus',
#   'around',
#   'even',
#   'still',
#   'death',
#   'rate',
#   'flu',
#   'coverage',
#   'got',
#   'stupid',
#   't',
#   'give',
#   'every',
#   'reason',
#   'lie',
#   'reason',
#   'tell',
#   'truth',
#   'real',
#   'roof',
#   'whole',
#   'thing',
#   'foul',
#   'play',
#   'guess',
#   'keep',
#   're',
#   'fine',
#   're',
#   'benefit',
#   'fear',
#   'agenda',
#   'believe',
#   'want',
#   'feel',
#   'depend',
#   'lead',
#   'protect',
#   'bet',
#   'first',
#   'line',
#   'vaccine',
#   'took',
#   'make',
#   'flu',
#   'vaccine',
#   'vaccine',
#   'none',
#   'yet',
#   'vaccine',
#   'novel',
#   'virus',
#   'six',
#   'don',
#   't',
#   'question',
#   'make',
#   'fear',
#   'many',
#   'people',
#   'die',
#   'yeah',
#   'good',
#   'luck'],
#  ['ambassador',
#   'whole',
#   'wrote',
#   'know',
#   'real',
#   'cause',
#   'idiot',
#   'amp',
#   'know',
#   'people',
#   'past',
#   'away',
#   'don',
#   't',
#   'care',
#   'fine',
#   'just',
#   'vulnerable'],
#  ['g',
#   'maybe',
#   'read',
#   's',
#   'flu',
#   'worse',
#   'glad',
#   'please',
#   'don',
#   't',
#   'everything',
#   'yet',
#   'know',
#   'anyone'],
#  ['ambassador', 'like', 'see', 're'],
#  ['g',
#   'told',
#   't',
#   'last',
#   'husband',
#   'sister',
#   'old',
#   'niece',
#   't',
#   'get',
#   'tell',
#   'one',
#   't',
#   's',
#   'real',
#   'etc',
#   'something',
#   'else',
#   's',
#   'need',
#   'vaccine',
#   'germ',
#   'x',
#   'etc',
#   'later',
#   'everyone',
#   'will',
#   'test',
#   'positive',
#   'rather',
#   'cautious',
#   'god',
#   'bless',
#   'family',
#   'please',
#   'please',
#   'look',
#   's',
#   'virus',
#   'stay',
#   'strong',
#   'safe'],
#  ['re', 'paid', 'troll'],
#  ['read', 'history', 'book'],
#  ['wow',
#   'sorry',
#   'committed',
#   'please',
#   'stay',
#   'church',
#   'rather',
#   'subject',
#   'maybe',
#   'can',
#   'ask',
#   'transfusion',
#   'can',
#   'benefit',
#   'blood'],
#  ['well',
#   'don',
#   't',
#   'take',
#   'nobody',
#   'will',
#   'take',
#   'vaccine',
#   'volunteer',
#   'every',
#   'vaccine',
#   'human',
#   'heroes',
#   'volunteer',
#   'can',
#   'check',
#   'safety',
#   'efficacy',
#   'vaccine',
#   'entire',
#   'don',
#   't',
#   'think',
#   'take',
#   'vaccine',
#   'though',
#   'pro'],
#  ['m', 'take'],
#  ['hey',
#   'polite',
#   'message',
#   'let',
#   'know',
#   're',
#   'wrong',
#   'per',
#   'said',
#   'vaccine',
#   'non',
#   'human',
#   'preliminary',
#   'success',
#   'vaccine',
#   'will',
#   'now'],
#  ['cool',
#   'whole',
#   'pandemic',
#   'sketchy',
#   'fear',
#   'global',
#   'response',
#   'lack',
#   'thereof'],
#  ['vaccine',
#   'will',
#   'chip',
#   'already',
#   'little',
#   'plastic',
#   'come',
#   'chip',
#   'thing',
#   'end',
#   'claim',
#   'will',
#   'doubt'],
#  ['s', 'hey', 'get', 'info', 'like'],
#  ['win',
#   'm',
#   'sure',
#   'page',
#   'minute',
#   'saw',
#   'video',
#   'trump',
#   'made',
#   'deal',
#   'company',
#   'like',
#   'produce',
#   'syringe',
#   'video',
#   'company'],
#  [],
#  ['info'],
#  ['don', 't', 's', 'poison'],
#  ['true', 'watch', 'last', 'video', 'channel'],
#  ['idiot', 'want', 'subject', 'like', 'lab', 'rat'],
#  ['well',
#   'simply',
#   'don',
#   't',
#   'volunteer',
#   'nobody',
#   'take',
#   'vaccine',
#   'volunteer',
#   'don',
#   't',
#   'think',
#   'take',
#   'vaccine',
#   'though',
#   'also',
#   'every',
#   'vaccine',
#   'human',
#   'heroes',
#   'volunteer',
#   'can',
#   'check',
#   'safety',
#   'efficacy',
#   'vaccine',
#   'entire'],
#  ['panda', 'yeah', 's', 'mandatory', 'now', 'soon', 'will'],
#  ['panda', 'amp', 'will', 'link', 'us', 'thank'],
#  ['panda',
#   'people',
#   'act',
#   'like',
#   'never',
#   'taken',
#   'pill',
#   'don',
#   't',
#   'know'],
#  ['panda', 'heroes', 'don', 't', 'mean', 'desperate'],
#  ['wow',
#   'just',
#   't',
#   'wait',
#   'felt',
#   'need',
#   'pre',
#   'strike',
#   'paranoid',
#   'delusion'],
#  ['lioness',
#   'roar',
#   'funny',
#   'oh',
#   'wait',
#   'serious',
#   'need',
#   'something',
#   'well',
#   'mental',
#   'health'],
#  ['panda',
#   'simple',
#   'poor',
#   'often',
#   'evil',
#   'big',
#   'promise',
#   'money',
#   'food',
#   'food',
#   'poor',
#   'descent',
#   'people',
#   'part',
#   'lab',
#   'rat',
#   'imagine',
#   'motivate',
#   'poor',
#   'person',
#   'volunteer',
#   's',
#   'love',
#   'can',
#   'assure',
#   's',
#   'money',
#   'food',
#   'feed',
#   'children',
#   'back',
#   'home',
#   'soon',
#   'will',
#   'little',
#   'children',
#   'right',
#   'damn'],
#  ['ditto'],
#  ['panda',
#   'yeah',
#   'heard',
#   'may',
#   'able',
#   'travel',
#   's',
#   'scary',
#   'let',
#   's',
#   'see',
#   'whether',
#   'fruition'],
#  ['s',
#   'guarantee',
#   're',
#   'will',
#   'inject',
#   'body',
#   'won',
#   't',
#   'knowledge',
#   'whatsoever',
#   'will',
#   'inject',
#   'body',
#   'faith',
#   'since',
#   'incentive',
#   'produce',
#   'safe',
#   'vaccine',
#   'since',
#   'now',
#   'big',
#   's',
#   'money',
#   're',
#   'well',
#   'dubious',
#   'therefore',
#   'sure',
#   'hell',
#   'will',
#   'become',
#   'mandatory',
#   'point',
#   'fraud',
#   'extension',
#   's',
#   'right',
#   'virus',
#   'polio',
#   'virus',
#   'virus',
#   'virus',
#   'etc',
#   'pathogen',
#   'part',
#   'immune',
#   'system'],
#  ['just', 'saw', 'us', 'pretty'],
#  [],
#  [],
#  [],
#  [],
#  ['re', 'right', 'know', 'vaccine'],
#  ['inject',
#   'u',
#   'u',
#   'build',
#   'many',
#   'throughout',
#   'history',
#   'people',
#   'due',
#   'left',
#   'life',
#   'long'],
#  ['good'],
#  ['said', 'don', 't', 'tell', 'anyone'],
#  ['infinite', 's', 'joke', 'way', 'hell', 'm', 'vaccine'],
#  ['lone', 'money'],
#  ['someone', 'mainstream', 'media'],
#  ['well', 's', 'will', 'also', 'check', 'make', 'sure', 'good', 'go'],
#  ['good', 'bud'],
#  [],
#  ['pandemic', 'status', 'south', 'high', 'recovery', 'rate', 'whole', 'world'],
#  ['must', 'rotten', 'potato'],
#  ['go', 'back', 'herd', 'sheep'],
#  ['tinfoil', 'invest'],
#  ['t', 'smart', 'get', 'go', 'bud'],
#  ['science',
#   'science',
#   'main',
#   'stream',
#   'media',
#   'check',
#   'declaration',
#   'panda',
#   'journal',
#   'lancet',
#   'forth',
#   'also',
#   'check',
#   'study',
#   'swindle',
#   'flu',
#   'journal',
#   'read',
#   'book',
#   'bill',
#   'expert',
#   'expertise',
#   'pandemic',
#   'also',
#   'check',
#   'world',
#   'forum',
#   'economy',
#   'can',
#   'also',
#   'check',
#   'excellent',
#   'work',
#   'will',
#   'desire',
#   'vaccine'],
#  ['go', 'ahead', 'demon'],
#  [],
#  ['bee',
#   'everyone',
#   'chip',
#   'whatever',
#   'want',
#   'get',
#   'life',
#   'want',
#   'want'],
#  [],
#  [],
#  ['public', 'will', 'soon', 'enough'],
#  ['bill', 'vaccine'],
#  ['create',
#   'something',
#   'held',
#   'safe',
#   'use',
#   're',
#   're',
#   'see',
#   'potential',
#   'injury',
#   'death'],
#  ['will',
#   'eat',
#   'hat',
#   'don',
#   't',
#   'get',
#   'sa',
#   'feel',
#   'free',
#   'contact',
#   'immune',
#   'ill',
#   'meal'],
#  ['just', 'shut'],
#  ['shut'],
#  [],
#  [],
#  ['need', 'shut'],
#  ['satanic', 'poison'],
#  ['will', 'rapture', 'children', 'will', 'rot', 'earth'],
#  ['satanic', 'poison', 'soon'],
#  ['agree'],
#  ['lemon',
#   'garlic',
#   'sunshine',
#   'healthy',
#   'get',
#   'vaccine',
#   'something',
#   'dangerous',
#   'smell',
#   'bat'],
#  ['king', 'may', 'right', 'think'],
#  [],
#  ['add', 'family', 'give'],
#  ['will', 'inject', 'plain', 'water'],
#  ['vaccine', 'choice'],
#  ['administer'],
#  ['give', 'poison', 'instead'],
#  ['can', 'still', 'fool', 'us'],
#  [],
#  ['u', 'crack'],
#  ['think', 'like', 'rubbish', 'credit', 'score', 'pay'],
#  ['co',
#   'talk',
#   'talk',
#   'make',
#   'price',
#   'country',
#   'course',
#   'rich',
#   'will',
#   'pay'],
#  ['re', 'person', 'thank'],
#  ['vaccine', 'kill', 'us', 'reduce'],
#  ['true',
#   'will',
#   'try',
#   'force',
#   'people',
#   'take',
#   'need',
#   'travel',
#   'forth',
#   'can',
#   'decline',
#   'vaccine',
#   'child'],
#  ['won', 't', 'people', 'will', 'accept', 'won', 't', 'real', 'side'],
#  ['true'],
#  ['family'],
#  [],
#  ['dare', 'common', 'sense'],
#  [],
#  ['tax', 'revenue', 'think', 'piggy', 'bank', 'empty'],
#  ['look', 'way', 'firm', 'virus', 'wake', 'people'],
#  ['make', 'watch', 'people', 'big', 'screen'],
#  ['will',
#   'will',
#   'somewhere',
#   'will',
#   'power',
#   'control',
#   'anyway',
#   'sad',
#   'always',
#   'can',
#   't',
#   'fund',
#   'can',
#   'fund',
#   'flashy',
#   'tax',
#   'money'],
#  ['w', 'h', 't'],
#  ['people'],
#  ['logic'],
#  ['top', 'show', 'lack', 'knowledge'],
#  [],
#  [],
#  [],
#  ['urge', 'go', 'look', 'fraud', 'medicine'],
#  ['just', 'never', 'trust', 'drug', 'corporate'],
#  ['hence', 'pandemic', 'get'],
#  ['love',
#   'like',
#   'people',
#   'don',
#   't',
#   'want',
#   'vaccine',
#   'everyone',
#   'anyway',
#   'must',
#   'thing',
#   'take',
#   'answer'],
#  ['end', 'day', 'just', 'flu', 'cure', 'flu'],
#  [],
#  ['earth',
#   'force',
#   'us',
#   'will',
#   'able',
#   'buy',
#   'food',
#   'travel',
#   'will',
#   'get',
#   'id',
#   'card',
#   'without',
#   'card',
#   'wont',
#   'enter'],
#  ['g', 'good', 's', 'vital', 'now', 'try', 'speed', 'devil', 'let', 'tell'],
#  ['don',
#   't',
#   'think',
#   'south',
#   'will',
#   'wait',
#   'long',
#   'large',
#   'world',
#   'guinea',
#   'pig',
#   's'],
#  ['mark', 'mark', 'hand'],
#  ['mark', 'beast', 'also'],
#  ['test', 'vaccine', 'top', 'now', 'want', 'administer', 'bottom', 'list'],
#  ['damn', 'right'],
#  ['maybe', 's', 'bad', 'thing'],
#  ['sa', 'put', 'bottom', 'list'],
#  [],
#  ['s', 'just', 'greed', 'people', 'can', 't', 'see', 'past', 'kill', 'many'],
#  ['take', 'vaccine'],
#  ['just', 'got', 'trial', 'sa', 'idea', 'placebo', 'group', 'though'],
#  ['maybe', 'listen', 'brother', 'sound', 'quite', 'naive'],
#  ['might', 'want', 'listen', 'like', 'real', 'world', 'paranoia'],
#  ['make', 'lose', 'faith', 'naive', 'can', 'people', 'simple', 'science'],
#  ['can', 're', 'naive'],
#  ['oh',
#   'lord',
#   'poor',
#   'soul',
#   'yet',
#   'know',
#   'data',
#   'right',
#   'either',
#   'data',
#   'important',
#   'anyone',
#   'never',
#   'use'],
#  ['think', 'vaccine', 'serious'],
#  ['maybe',
#   'don',
#   't',
#   'know',
#   'can',
#   'sure',
#   're',
#   'also',
#   'even',
#   't',
#   'vaccine'],
#  ['can',
#   'sure',
#   'see',
#   'practice',
#   'go',
#   'fit',
#   'inside',
#   'vaccine',
#   'shot',
#   'without',
#   'like',
#   'everyone',
#   'seeing',
#   'chip',
#   'put',
#   'need',
#   'nowhere',
#   'near',
#   't',
#   'theory',
#   'equivalent',
#   'water',
#   'may',
#   'can',
#   't',
#   'top',
#   'data',
#   'speak',
#   'somewhere',
#   'world',
#   'pretty',
#   'go',
#   'chip',
#   'everyone',
#   'without',
#   'consent',
#   'free',
#   'will'],
#  ['maybe',
#   'just',
#   't',
#   'sorry',
#   'opinion',
#   'just',
#   'fact',
#   'yea',
#   'can',
#   'opinion',
#   'legitimacy',
#   'vaccine',
#   's',
#   'self',
#   'just',
#   'simple',
#   'fact',
#   'stupid',
#   's',
#   'world',
#   'live',
#   'don',
#   't',
#   'tech',
#   'hide',
#   'liquid',
#   'mean',
#   'don',
#   't',
#   'think',
#   'people',
#   'will',
#   'start',
#   'notice',
#   'chip'],
#  ['t',
#   'tell',
#   'technology',
#   'behind',
#   'secret',
#   'tech',
#   's',
#   'micro',
#   'chip',
#   'head',
#   's',
#   'ancient',
#   'tech',
#   'now',
#   'technology',
#   'see'],
#  ['just', 'one', 'dose', 'result', 'injury', 'like', 'paralysis'],
#  ['people',
#   'don',
#   't',
#   'seem',
#   'can',
#   'wrong',
#   'inadequate',
#   'data',
#   'can',
#   'simply',
#   'bought',
#   'almighty',
#   'dollar'],
#  ['s',
#   'paranoia',
#   'truth',
#   'later',
#   'much',
#   'history',
#   'rather',
#   'err',
#   'side',
#   'caution',
#   'worse'],
#  ['science',
#   'good',
#   'new',
#   'knowledge',
#   'scientific',
#   'ago',
#   'many',
#   'harmful',
#   'arena',
#   'safe',
#   'will',
#   'often',
#   'personal',
#   'agenda',
#   'grant',
#   'ego',
#   'integrity',
#   'integrity',
#   'people',
#   'person',
#   'person',
#   'omniscient'],
#  ['need', 'beyond', 'page', 'search', 'common', 'knowledge', 'bill'],
#  ['material',
#   'vaccine',
#   'tid',
#   'bit',
#   'kind',
#   're',
#   'right',
#   'different',
#   'everything',
#   'fed',
#   'us',
#   'like'],
#  ['point',
#   'like',
#   'even',
#   'said',
#   'everything',
#   'need',
#   'believe',
#   'spend',
#   'get',
#   'vital',
#   'info',
#   'important'],
#  ['yea',
#   'know',
#   'otherwise',
#   'just',
#   'found',
#   'late',
#   'night',
#   'web',
#   'search'],
#  ['blue',
#   'mantis',
#   'doubt',
#   'first',
#   'part',
#   'man',
#   'point',
#   'everything',
#   'need',
#   'ago',
#   'give',
#   'point'],
#  ['said',
#   'rate',
#   'recovery',
#   'see',
#   'now',
#   'people',
#   'dead',
#   'scare',
#   'us',
#   'vaccine',
#   'pass'],
#  [],
#  [],
#  ['oh', 'man', 'just', 'employ', 'peter', 'can', 'job', 'world'],
#  ['expert', 'expect', 'answer', 'legitimate', 'question', 'just', 'face'],
#  ['much'],
#  [],
#  [],
#  ['yeah',
#   'true',
#   'bill',
#   'us',
#   'still',
#   'believe',
#   'will',
#   'struggle',
#   'south',
#   'though',
#   'can',
#   'bribe',
#   'people',
#   'chicken',
#   'just',
#   'add',
#   'free',
#   'meal',
#   'vaccine',
#   'country',
#   'will',
#   'storm'],
#  ['terrible', 'u', 'educate', 'self'],
#  ['allow',
#   'stuff',
#   'enter',
#   'south',
#   'even',
#   'like',
#   'idea',
#   'new',
#   'world',
#   'order',
#   'conspiracy',
#   'theory',
#   'vaccine',
#   'incident',
#   'may',
#   'every',
#   'aspect'],
#  ['thank', 'sir', 'fool', 'sell', 'sa', 'deep', 'state', 'must', 'wake'],
#  ['billion',
#   'bill',
#   'people',
#   'don',
#   't',
#   'notice',
#   'sa',
#   'health',
#   'part',
#   'foundation',
#   'now'],
#  ['yeah',
#   'just',
#   'made',
#   'make',
#   'people',
#   'panic',
#   'fear',
#   'can',
#   'control',
#   'world'],
#  ['wish', 'people', 'can', 'excuse', 'agenda', 'world'],
#  ['money', 'bill', 'foundation'],
#  ['wonder',
#   'clue',
#   'already',
#   'know',
#   'can',
#   't',
#   'guess',
#   'must',
#   'conspiracy',
#   'huh'],
#  ['vaccine'],
#  ['foolish'],
#  ['say',
#   'scam',
#   'husband',
#   'moment',
#   's',
#   'seen',
#   'mild',
#   'careful',
#   'still',
#   'got',
#   'man',
#   'husband',
#   'week',
#   'spent',
#   'hospital',
#   'room',
#   'four',
#   'men',
#   'imagine',
#   'must',
#   's',
#   'nothing',
#   'joke'],
#  ['vaccine'],
#  ['glad', 're'],
#  ['stop', 'stupid'],
#  ['bill'],
#  ['can',
#   'see',
#   'soon',
#   'die',
#   'stupid',
#   'people',
#   'think',
#   're',
#   'foolish',
#   'can',
#   't',
#   'see'],
#  ['payroll'],
#  ['just'],
#  ['late',
#   'everyone',
#   'threat',
#   's',
#   'mass',
#   'media',
#   'consume',
#   'believe',
#   'everything',
#   'hear',
#   'without',
#   'question',
#   'anyone',
#   'perspective',
#   'shutdown',
#   'conspiracy',
#   'theorist',
#   'rotten',
#   'zombie',
#   's'],
#  ['impossible', 'turn', 'zombie'],
#  [],
#  ['tell',
#   'media',
#   'talk',
#   'sex',
#   'trafficking',
#   'pandemic',
#   'world',
#   'one',
#   'poverty',
#   'crisis',
#   'one',
#   'immense',
#   'corruption',
#   'state',
#   'capture',
#   'one',
#   's',
#   'country',
#   'one',
#   'many',
#   'people',
#   'rape',
#   'murder',
#   'drug',
#   'basis',
#   'one',
#   'talk',
#   'yellow',
#   'fever',
#   'china',
#   'virus',
#   'survival',
#   'rate',
#   'yet',
#   'just',
#   'mention',
#   'word',
#   'excuse',
#   'anything',
#   'screw',
#   'lock',
#   'want',
#   'destroy',
#   'honest',
#   'hardworking',
#   'innocent',
#   'law',
#   'stop',
#   'tax',
#   'stop',
#   'lying',
#   'us',
#   'every',
#   'single',
#   'day',
#   'lame',
#   'ass',
#   'mainstream',
#   'media',
#   'people',
#   'fed',
#   'just',
#   'want',
#   'family',
#   'put',
#   'food',
#   'table',
#   'live',
#   'damn',
#   'without',
#   'constant',
#   'interference',
#   'tiny',
#   'top',
#   'think',
#   'can',
#   'dictate',
#   'us'],
#  ['watch', 'much'],
#  ['never', 'made', 'vaccine'],
#  ['trickle', 'tech', 'like', 'like', 'flu', 's', 'thing', 'similar'],
#  ['country', 'anyway'],
#  ['can', 'get', 'rid', 'get', 'proper', 'south', 'can', 'great'],
#  ['true', 'can', 'see', 'human', 'skin'],
#  ['yeah'],
#  [],
#  ['know',
#   'can',
#   'sue',
#   'lost',
#   'somebody',
#   'family',
#   'can',
#   'file',
#   'lawsuit',
#   'will',
#   'pay',
#   'pay',
#   'pay',
#   'go',
#   'get',
#   'money',
#   'fellow',
#   'south',
#   'sue',
#   'don',
#   't',
#   'pandemic',
#   'go',
#   'get',
#   'rich'],
#  ['beyond',
#   'south',
#   'see',
#   'successful',
#   'even',
#   'get',
#   'relief',
#   'heard',
#   'ask',
#   'around',
#   'one',
#   'got'],
#  ['beyond',
#   'yeah',
#   'don',
#   't',
#   'sa',
#   'don',
#   't',
#   'even',
#   'fix',
#   'good',
#   'luck',
#   'anyone',
#   'anything'],
#  [],
#  ['well', 'said', 'point', 'stop'],
#  ['flu', 'etc', 'see', 'side'],
#  ['won',
#   't',
#   'stop',
#   'think',
#   'bad',
#   'wait',
#   'store',
#   'us',
#   'promotion',
#   'next',
#   'year',
#   'rank'],
#  ['s', 'sign'],
#  ['m'],
#  ['s',
#   'proven',
#   'proven',
#   'safe',
#   'won',
#   't',
#   'interfere',
#   'made',
#   's',
#   'may',
#   'steel',
#   'cap',
#   'safety',
#   'standby',
#   'kick',
#   'away',
#   'great',
#   'day',
#   'may',
#   'end',
#   'well'],
#  ['agree',
#   'vaccine',
#   'biblical',
#   'many',
#   'people',
#   'know',
#   'many',
#   'just',
#   'take',
#   're',
#   'given',
#   'may',
#   'end',
#   'well',
#   'thank',
#   'god',
#   'bless'],
#  ['thing'],
#  [],
#  ['god', 'can', 'heal', 'everything'],
#  ['just', 'like', 'dying', 'without'],
#  ['old', 'dumb', 'enough', 'get'],
#  ['can'],
#  ['m', 'line', 'go', 'take', 'care'],
#  ['like',
#   'see',
#   'first',
#   'south',
#   'must',
#   'first',
#   'vaccine',
#   'poor',
#   'black',
#   'people'],
#  ['aspen', 'will', 'behalf', 'j', 'amp', 'j'],
#  ['great', 'job', 'engine', 'country', 'like', 'car', 's'],
#  ['even',
#   'bout',
#   'whether',
#   'vaccine',
#   'need',
#   'wait',
#   's',
#   'money',
#   'thing',
#   'people'],
#  [],
#  ['good', 'need'],
#  ['don',
#   't',
#   'take',
#   'vaccine',
#   'beaten',
#   'previous',
#   'vaccine',
#   'half',
#   'trial',
#   'period',
#   'maximum',
#   'data',
#   'prove',
#   'efficacy',
#   'safety',
#   'much',
#   'case',
#   'chance',
#   'survival',
#   'global',
#   'average',
#   't',
#   'cell',
#   'pre',
#   'corona',
#   'virus',
#   'least',
#   'vaccine',
#   'yesterday',
#   'tomorrow',
#   'country',
#   'least',
#   'people',
#   'day'],
#  [],
#  ['people', 'stupid', 's', 'kind', 'strange', 'people'],
#  ['s',
#   'f',
#   'well',
#   'think',
#   'way',
#   'south',
#   'don',
#   't',
#   'people',
#   'middle',
#   'religious',
#   'white',
#   'get',
#   'info'],
#  ['religious', 'fake', 'got'],
#  [],
#  ['look', 'company', 'supply', 'amp', 'etc'],
#  ['t', 'many', 'us'],
#  ['agree'],
#  ['re',
#   'guinea',
#   'mate',
#   'w',
#   'h',
#   'o',
#   'close',
#   'don',
#   't',
#   'told',
#   'must',
#   'take',
#   'mandatory',
#   'vaccine',
#   'else',
#   'can',
#   't',
#   'travel',
#   'work',
#   'let',
#   's',
#   'see'],
#  ['great', 'perspective'],
#  ['won',
#   't',
#   'enough',
#   'make',
#   'mandatory',
#   'don',
#   't',
#   'see',
#   'kind',
#   'law',
#   'south',
#   'even',
#   'social',
#   'look',
#   'around'],
#  ['ploy', 'sa', 'public', 'lust', 'vaccine', 'psychology'],
#  ['s',
#   'will',
#   'monitor',
#   'vs',
#   'vaccine',
#   'adverse',
#   'vaccine',
#   'will',
#   'significant',
#   'amp',
#   'mine'],
#  [],
#  ['well',
#   'already',
#   'part',
#   's',
#   'dumb',
#   'south',
#   'need',
#   'white',
#   'south',
#   'western',
#   'first',
#   'world',
#   'now',
#   'move',
#   'make',
#   'short',
#   'medium',
#   'long',
#   'term',
#   'plan',
#   'extent',
#   'almost',
#   'broken',
#   'country',
#   'new',
#   'world',
#   'order',
#   'agenda',
#   'stupid',
#   'bit',
#   'challenge',
#   'evil',
#   'satan',
#   's',
#   'agenda',
#   'sa',
#   'rest',
#   'however',
#   'also',
#   'country',
#   'across',
#   'racial',
#   'need',
#   'now',
#   'like',
#   'land',
#   'etc',
#   'us',
#   'one',
#   'another',
#   'let',
#   's',
#   'buy',
#   'instead',
#   'let',
#   's',
#   'go',
#   'media',
#   'fight',
#   'inequality',
#   'create',
#   't',
#   'eliminate',
#   'social',
#   'crap',
#   'start',
#   'civil',
#   'sense',
#   'amongst',
#   'must',
#   'become',
#   'sister',
#   's',
#   'skin',
#   'race',
#   'culture',
#   'yesterday'],
#  ['sure'],
#  ['vaccine', 'wont', 'progress', 'hope', 'develop', 'one'],
#  ['u',
#   'will',
#   'get',
#   'different',
#   'vaccine',
#   'event',
#   'know',
#   'try',
#   'people',
#   'mind'],
#  ['agree'],
#  ['already',
#   'people',
#   'voluntary',
#   'receive',
#   'vaccine',
#   'hence',
#   'percentage',
#   'rate',
#   'nobody',
#   'now',
#   'will'],
#  ['get',
#   'man',
#   'm',
#   'nervous',
#   'well',
#   'take',
#   'm',
#   'sure',
#   'whether',
#   'ill',
#   'take',
#   'exact',
#   'reason',
#   'mention',
#   's',
#   'caution',
#   'amp',
#   'nefarious',
#   'ulterior',
#   'bill',
#   'sort',
#   'deep',
#   'state',
#   'control',
#   'conspiracy'],
#  ['half', 'people', 'just', 'use', 'give', 'break'],
#  [],
#  ['bill',
#   't',
#   'make',
#   'vaccine',
#   'multi',
#   'billion',
#   'dollar',
#   'humanitarian',
#   'entity',
#   'create',
#   'vaccine',
#   'smooth',
#   'take',
#   'one',
#   'sentence',
#   'said',
#   'growth',
#   'mean',
#   's',
#   'us',
#   'vaccine',
#   'utter',
#   'lead',
#   'rate',
#   'turn',
#   'people',
#   'children',
#   'm',
#   'sure',
#   'can',
#   'figure',
#   'decrease',
#   'growth'],
#  ['fool', 'man', 'evil'],
#  ['g'],
#  ['also',
#   'water',
#   're',
#   'future',
#   'little',
#   'water',
#   'land',
#   'also',
#   'issue',
#   'course',
#   's',
#   'point',
#   'educate',
#   'people'],
#  ['people',
#   'children',
#   'infant',
#   'low',
#   'debate',
#   'show',
#   'clear',
#   'day',
#   'hit',
#   'lead',
#   'birth',
#   'don',
#   't',
#   'need',
#   'hedge',
#   'will',
#   'survive',
#   'take',
#   'care',
#   'old',
#   'age',
#   's',
#   'child',
#   'will',
#   'make',
#   'don',
#   't',
#   'need',
#   'children',
#   'chance',
#   'current',
#   'child',
#   'wish',
#   'paid',
#   'someone',
#   'talk'],
#  ['s',
#   'fool',
#   'man',
#   'convince',
#   's',
#   'bill',
#   'global',
#   'tyrant',
#   'said',
#   'don',
#   't',
#   'blind'],
#  ['wow',
#   't',
#   'debate',
#   's',
#   'data',
#   'article',
#   'see',
#   'truth',
#   'now',
#   'complete',
#   'bogus',
#   'world',
#   't',
#   'm',
#   'done',
#   'utter',
#   'now'],
#  ['correct',
#   'agree',
#   'however',
#   'flaw',
#   'bill',
#   's',
#   'plan',
#   'child',
#   'rate',
#   't',
#   'lead',
#   'will',
#   'pop',
#   'amount',
#   'children',
#   'whether',
#   'live',
#   'will',
#   'increase',
#   'friend',
#   'think',
#   'vaccine',
#   'might',
#   'good',
#   'idea'],
#  ['yeah', 'don', 't', 'test', 'faith', 'just', 'take', 'vaccine'],
#  ['black', 'person', 'right'],
#  [],
#  ['mean', 'faith'],
#  ['just', 'people', 'dead', 'nation', 'world'],
#  ['don',
#   't',
#   'mind',
#   'dead',
#   'wow',
#   'say',
#   'nation',
#   'find',
#   'offensive',
#   'ma',
#   'guy'],
#  ['m', 'black', 'wrong', 'even', 'put', 'don', 't', 'think'],
#  ['spiritual'],
#  ['mark', 'beast'],
#  ['wow',
#   'laugh',
#   'just',
#   'don',
#   't',
#   'vaccine',
#   'alone',
#   'stop',
#   'belief',
#   'one',
#   'take',
#   'don',
#   't',
#   'call',
#   'person',
#   'dead',
#   'something',
#   'let',
#   'person'],
#  ['never',
#   'anyone',
#   'just',
#   'just',
#   'much',
#   'given',
#   'people',
#   'amp',
#   'can',
#   'check'],
#  [],
#  ['g', 'home', 'school', 'will', 'let', 'beast', 'system', 'eat', 'self'],
#  ['vaccine',
#   'last',
#   'shot',
#   'grace',
#   'choose',
#   'believe',
#   'god',
#   's',
#   'man',
#   's',
#   'much',
#   'fear',
#   'put',
#   'vaccine',
#   'revelation',
#   'us',
#   'mark',
#   'beast',
#   'will',
#   'put',
#   's',
#   'vaccine'],
#  ['know', 'stop'],
#  [],
#  ['need', 'anything', 'alter', 's'],
#  [],
#  ['need'],
#  ['oh', 'hell', 'even', 'corona', 'ask', 'health'],
#  ['noble', 'god', 'give', 'us', 'inspiration', 'don', 't', 'solve', 'us'],
#  ['see',
#   'world',
#   'un',
#   'control',
#   'grid',
#   't',
#   'character',
#   'yet',
#   'conspiracy',
#   'now',
#   'rant',
#   'cost',
#   'life'],
#  [],
#  ['still',
#   'able',
#   'find',
#   'suspect',
#   'language',
#   'draw',
#   'attention',
#   'although',
#   'beginning',
#   'found',
#   'speech',
#   'topic',
#   'channel'],
#  ['brother',
#   'will',
#   'search',
#   'video',
#   'us',
#   'proxy',
#   'country',
#   'look',
#   'become',
#   's',
#   'new',
#   'found',
#   'freedom'],
#  ['un',
#   'speech',
#   'even',
#   'find',
#   'decent',
#   'quality',
#   'info',
#   'appreciate',
#   's',
#   'hard',
#   'find',
#   'people',
#   'tell',
#   'truth',
#   'nowadays'],
#  ['man', 'made', 'un', 'speech'],
#  ['need', 'cringe', 'time', 'wake', 'find', 'light', 'will', 'go'],
#  ['de', 'wet', 'people', 'just', 'wow'],
#  ['people', 'come'],
#  ['sane', 'people', 'propaganda', 'mean'],
#  [],
#  ['must', 'south', 'always', 'can', 'go', 'try', 'another', 'country'],
#  ['just', 'heard', 'audio', 'south', 'first', 'country'],
#  ['black', 'corrupt', 'proven', 'throughout', 'give', 'sell', 'mother'],
#  ['let', 'take', 'vaccine', 'first', 'give', 'us', 'see'],
#  ['thank', 'god', 'corrupt'],
#  ['will', 'force', 'black', 'people', 's', 'first', 'vaccine'],
#  ['agree'],
#  ['cry', 'anything', 'turn', 'bad', 'future'],
#  ['can', 'try', 'people', 'power', 'say', 'trust', 'nobody'],
#  ['thank', 'take', 'will', 'rather', 'take', 'tea'],
#  ['will', 'start', 'money'],
#  ['us', 'dare'],
#  ['damn',
#   'don',
#   't',
#   'know',
#   'got',
#   'm',
#   'sorry',
#   'everyone',
#   'hope',
#   'people',
#   'can',
#   'feel',
#   'like',
#   'way',
#   'feel',
#   'now',
#   'maybe',
#   'value',
#   'human',
#   'sorry'],
#  ['problem'],
#  ['s', 'stupid'],
#  ['way'],
#  ['s', 'problem'],
#  ['true'],
#  ['go', 'check', 'name', 'spiritual', 'will', 'know'],
#  ['k'],
#  ['hope', 'teenage', 'mutant', 'turtle'],
#  ['give', 'us', 'link'],
#  ['k', 'won', 't', 'genetic', 'make'],
#  ['m', 'run', 'away'],
#  ['saw', 'people', 'got', 'sick', 'anyone', 'blind', 'bat'],
#  ['patent', 'within', 'vaccine'],
#  ['fine', 'wont', 'catch', 'corona', 'can', 'get', 'vaccine'],
#  ['t',
#   'option',
#   'lift',
#   'vaccine',
#   'choice',
#   'vaccinate',
#   's',
#   'smart',
#   'move',
#   'every',
#   'possible',
#   'important'],
#  ['even'],
#  ['s',
#   'wrong',
#   'nothing',
#   'see',
#   'pretty',
#   'much',
#   'work',
#   'herd',
#   'public',
#   'good',
#   'state',
#   'may',
#   'implement',
#   'coercive'],
#  ['hazardous', 'micro'],
#  ['t', 'people', 'still', 'dying', 'smallpox'],
#  ['need', 'standard', 'medicine'],
#  ['sad', 'argument', 'small', 'vaccine'],
#  ['want', 'smallpox', 't', 'd', 'live'],
#  ['hazardous',
#   'haven',
#   't',
#   'fact',
#   'hazardous',
#   'done',
#   'give',
#   'fair',
#   'example',
#   'don',
#   't',
#   'say',
#   'autism',
#   't',
#   'true'],
#  ['kid', 'like', 'week', 'bad', 'need'],
#  ['perception', 'man'],
#  ['vaccine', 'can', 'lab', 'rat', 'want'],
#  ['stop',
#   'can',
#   'see',
#   're',
#   'soon',
#   'like',
#   'comment',
#   'little',
#   's',
#   'sad',
#   'need',
#   'like',
#   'know',
#   're',
#   'everyone'],
#  [],
#  ['brother', 's', 'son', 'got', 's', 'vaccine'],
#  ['guess', 'guy', 'apple', 'hazardous', 'troll'],
#  ['s', 'vaccine', 'virus', 'extinct'],
#  ['virus', 'extinct'],
#  [],
#  [],
#  ['sure', 'extinct', 't', 'right', 'smallpox', 'since', 's', 'vaccine'],
#  ['don', 't', 'watch', 'man'],
#  ['k'],
#  [],
#  ['load', 'will', 'never', 'stop', 'south'],
#  ['yeah'],
#  ['load', 'will', 'never', 'die', 'south'],
#  ['opinion', 'two', 'don', 't', 'exclusive'],
#  ['guy', 'several', 'new', 'world', 'order', 'industrial', 'revolution'],
#  ['pretty', 'proficient'],
#  ['g', 'claim'],
#  ['let', 'take', 'vaccine', 'first', 'give', 'us', 'see'],
#  ['behind', 'must'],
#  [],
#  ['new', 'normal', 'permanent', 'great', 'radical', 'top', 'worldwide'],
#  ['might', 'need', 'go', 'look', 'definition', 'perhaps', 'go'],
#  ['fully',
#   'aware',
#   's',
#   'many',
#   'far',
#   'rouge',
#   'etc',
#   't',
#   'even',
#   'need',
#   't',
#   'already',
#   'know',
#   'read',
#   'woke',
#   'time',
#   'magazine',
#   's',
#   'cover',
#   'story',
#   'great',
#   'put',
#   'correct',
#   'state',
#   'mind',
#   'accompany',
#   'next',
#   's',
#   'conference',
#   'great',
#   'will',
#   'item',
#   'agenda',
#   'rubric',
#   'read',
#   'top',
#   'conference',
#   's',
#   'new',
#   'book',
#   'great',
#   'great',
#   's',
#   'strategy',
#   'rally',
#   'global',
#   'public',
#   'private',
#   'institution',
#   'global',
#   'command',
#   'economy',
#   's',
#   'core',
#   'doctrine',
#   'good',
#   'luck'],
#  ['rather',
#   'argue',
#   's',
#   'core',
#   'modern',
#   'labour',
#   'law',
#   'ago',
#   'anti',
#   'slavery',
#   'almost',
#   'always',
#   'much',
#   'private',
#   'sector',
#   'stall',
#   'example',
#   'like',
#   'china',
#   'paranoid',
#   'take',
#   'power',
#   'everyone',
#   'yah',
#   'point',
#   's',
#   'always',
#   'vague',
#   'old',
#   'mess'],
#  ['insightful',
#   'input',
#   'time',
#   's',
#   'cover',
#   'feature',
#   'almost',
#   'woke',
#   'prince',
#   'gore',
#   'un',
#   'prestigious',
#   'un',
#   's',
#   'agenda',
#   'entire',
#   'world',
#   's',
#   'etc',
#   'etc',
#   'conspiracy',
#   'must',
#   'right',
#   'thank',
#   'much'],
#  ['don', 't', 'petty', 'just', 'might'],
#  ['mean',
#   'sarcasm',
#   'willful',
#   'history',
#   'want',
#   'see',
#   'style',
#   'thou',
#   'petty',
#   'read',
#   'second'],
#  ['s',
#   'petty',
#   'response',
#   'none',
#   'made',
#   'sarcastic',
#   'point',
#   'never',
#   'made'],
#  [],
#  ['still',
#   'argument',
#   'incapable',
#   'just',
#   'grown',
#   'use',
#   'told',
#   'think',
#   'believe',
#   't',
#   'said',
#   'right',
#   'wrong',
#   'able',
#   'correct',
#   'least',
#   'articulate',
#   'think',
#   'might',
#   'wrong',
#   'one',
#   'conspiracy',
#   'can',
#   't',
#   'discussion',
#   'zero',
#   'pot',
#   'also',
#   'zero',
#   'imagine',
#   'also',
#   'side',
#   'greater',
#   'good'],
#  [],
#  ['fact', 'check', 'proven', 'primary', 'cause'],
#  ['please'],
#  ['can', 'say', 'average', 'pass'],
#  ['video', 'said', 'cause', 'got', 'please', 'go', 'back', 'school', 'learn'],
#  ['sure'],
#  ['mate',
#   'don',
#   't',
#   'even',
#   'people',
#   'reason',
#   'now',
#   'let',
#   'pass',
#   'average',
#   'even',
#   'corrupt',
#   'cringe'],
#  ['now',
#   'see',
#   'vaccine',
#   'little',
#   'get',
#   'blood',
#   'blood',
#   'see',
#   'now',
#   'little',
#   'vaccine',
#   'well',
#   'suppose',
#   'even',
#   'wrote',
#   'just',
#   'thought',
#   'try',
#   'explain',
#   'side'],
#  ['little', 'blood', 'lost'],
#  ['funny', 'thing', 'people', 'believe', 'think', 'smart'],
#  ['don',
#   't',
#   'let',
#   'mainstream',
#   'media',
#   'fool',
#   'people',
#   'scientist',
#   'doctor',
#   'money',
#   'world',
#   'people',
#   'want',
#   'whole',
#   'world',
#   'don',
#   't',
#   'sheep'],
#  ['pretty', 'well'],
#  ['sound', 'like', 'mainstream', 'puppet', 'parrot'],
#  ['van',
#   'agree',
#   'mainstream',
#   'media',
#   'one',
#   'change',
#   'seen',
#   'family',
#   'around',
#   'succumb',
#   'virus'],
#  ['m',
#   'sorry',
#   'truly',
#   'm',
#   'virus',
#   'fake',
#   's',
#   'true',
#   'virus',
#   'manipulate',
#   'people',
#   's',
#   'right',
#   'freedom',
#   's',
#   'true',
#   'pun',
#   's',
#   'order',
#   'write',
#   'even',
#   'mere',
#   'car',
#   'accident',
#   'will',
#   'make',
#   'vaccine',
#   'mandatory'],
#  ['comment', 'beginning', 'lose', 'hope', 's'],
#  [],
#  ['know',
#   'work',
#   's',
#   'just',
#   'don',
#   't',
#   'want',
#   'also',
#   'time',
#   'check',
#   'will',
#   'affect',
#   'epilepsy',
#   'doctor',
#   'birth'],
#  ['refrain',
#   'vaccine',
#   'due',
#   'fail',
#   'people',
#   'without',
#   'reason',
#   'without',
#   'authentic',
#   'proven',
#   'back'],
#  ['nothing', 'just', 'believe', 'virus'],
#  ['let', 'take', 'vaccine', 'first', 'give', 'us', 'see'],
#  ['mark', 'will', 'right', 'hand', 's', 'vaccine'],
#  ['us', 'mark', 'beast'],
#  ['don', 't', 'think', 'mark', 'mark', 'will', 'come', 'rapture'],
#  ['like', 'people', 'already', 'video'],
#  ['true', 'country', 's', 'already'],
#  ['blasphemous',
#   'use',
#   'bill',
#   's',
#   'name',
#   'appropriate',
#   'answer',
#   'rubbish',
#   'mate',
#   'need',
#   'find',
#   'first',
#   'order',
#   'respect'],
#  ['friend',
#   'pity',
#   'people',
#   'don',
#   't',
#   'know',
#   'truth',
#   'behind',
#   'fake',
#   's',
#   'way',
#   'mark'],
#  ['yeah',
#   'vaccine',
#   'can',
#   'take',
#   'will',
#   'hit',
#   'm',
#   'smart',
#   'therefore',
#   'know',
#   'complex',
#   'run',
#   'get',
#   'first',
#   'decry',
#   'people',
#   's',
#   'promote',
#   'free'],
#  ['world',
#   'proper',
#   'will',
#   'see',
#   'along',
#   'poor',
#   'ill',
#   'people',
#   'will',
#   'left',
#   'now',
#   'want',
#   'war',
#   'torn',
#   'world',
#   'everyone',
#   'please',
#   'push',
#   'world'],
#  ['agree', 'people', 'like', 'first', 'list'],
#  ['can',
#   'get',
#   'flu',
#   'vaccine',
#   'pretty',
#   'much',
#   'doctor',
#   'problem',
#   'flu',
#   'widespread',
#   'many',
#   'can',
#   'lead',
#   'many',
#   'virus',
#   'mutate',
#   'common',
#   'cold',
#   'flu',
#   'will',
#   'last',
#   'two',
#   'flu',
#   'vaccine',
#   'already',
#   'obsolete',
#   'time',
#   's'],
#  ['know',
#   's',
#   'new',
#   'vaccine',
#   'flue',
#   'like',
#   'every',
#   'couple',
#   'right',
#   't',
#   'think'],
#  ['vaccine'],
#  ['trust', 's', 'trust'],
#  ['m', 'm', 'vector', 'version', 'vector', 'sputnik', 'vaccine'],
#  ['s',
#   'said',
#   'mark',
#   'beast',
#   'although',
#   'mark',
#   'beast',
#   'chip',
#   'right',
#   'hand',
#   'vaccine',
#   'slave',
#   'psycho'],
#  ['vaccine', 'chip', 'will', 'right', 'hand', 'vaccine'],
#  ['revelation',
#   't',
#   'mark',
#   'beast',
#   'will',
#   'will',
#   'take',
#   'place',
#   'rapture',
#   'please',
#   'read',
#   'revelation',
#   'full',
#   'rapture',
#   'decide',
#   'take',
#   'vaccine',
#   'faith',
#   'choose',
#   'believe',
#   'god',
#   's',
#   'vaccine',
#   'last',
#   'chance',
#   'grace',
#   'relief',
#   'god',
#   'rapture',
#   'will',
#   'bad',
#   'miss',
#   'people',
#   'will',
#   'survive',
#   'ask',
#   'god',
#   's',
#   'guidance',
#   'will',
#   'direct'],
#  [],
#  ['recovery'],
#  [],
#  ['proper', 'vaccine', 'just', 'huge', 'amount', 'money', 'still'],
#  ['want', 'world', 'go', 'back', 'normal', 'cause', 'stock', 'market'],
#  ['drake',
#   'point',
#   'said',
#   'cant',
#   'speed',
#   'time',
#   'furthermore',
#   'death',
#   'rate',
#   'constitute',
#   'vaccine'],
#  ['drake',
#   'still',
#   'long',
#   'term',
#   'will',
#   'take',
#   's',
#   'people',
#   'will',
#   'wary'],
#  ['t', 'create', 'vaccine', 'scratch', 'vaccine', 'stop'],
#  ['seen',
#   'speak',
#   'whether',
#   'private',
#   'public',
#   'sector',
#   'academia',
#   'business',
#   'health',
#   'agriculture',
#   'tech',
#   'science',
#   'etc',
#   'goes',
#   'even',
#   'far',
#   'beyond',
#   'revolution',
#   'just',
#   'revolution',
#   'first',
#   'major',
#   'successful',
#   'event',
#   'now',
#   'm',
#   'everything',
#   'taught',
#   'school',
#   'truly'],
#  [],
#  [],
#  ['global', 'come'],
#  ['re', 'ridiculous'],
#  ['us'],
#  ['please', 'tell', 'don', 't'],
#  ['maxwell', 's', 'mark', 'beast'],
#  ['maxwell', 'new', 'world', 'order', 'great'],
#  ['maxwell', 's', 'evil', 'serious'],
#  [],
#  ['let', 'take', 'vaccine', 'first', 'give', 'us', 'see'],
#  ['come', 'together', 'will', 'fall', 'together', 'will', 'stand'],
#  [],
#  ['hilarious'],
#  ['let', 'take', 'vaccine', 'first', 'give', 'us', 'see'],
#  ['documentary', 'trust', 'goes', 'detail'],
#  ['let', 'take', 'vaccine', 'first', 'give', 'us', 'see'],
#  ['get', 'go', 'pull', 'something'],
#  ['let', 'take', 'vaccine', 'first', 'give', 'us', 'see'],
#  [],
#  ['good', 'question'],
#  ['point', 'survival', 'rate', 'least'],
#  ['yeah',
#   's',
#   'vaccine',
#   'never',
#   'last',
#   'one',
#   'say',
#   's',
#   'solution',
#   'will',
#   'alter',
#   'form',
#   'sold',
#   'soul',
#   're',
#   'whole',
#   'thing',
#   'giant',
#   'scam',
#   'feet',
#   'social',
#   'feet',
#   'feet',
#   'feet',
#   'side'],
#  ['vaccine', 'symptomatic', 'virus', 'fishy', 'fishy'],
#  ['tell'],
#  ['radioactive',
#   'million',
#   'people',
#   'heart',
#   'must',
#   'now',
#   'death',
#   'stroke',
#   'road',
#   'diabetes',
#   'etc',
#   'also',
#   'wonder',
#   'many',
#   'people',
#   'something',
#   'else',
#   'economy',
#   'million',
#   'million',
#   'face',
#   'risk',
#   'mere'],
#  ['radioactive',
#   'admitted',
#   'stop',
#   'mainstream',
#   'propaganda',
#   'think',
#   'little',
#   'can',
#   't',
#   'stupid'],
#  ['radioactive',
#   'many',
#   't',
#   'even',
#   'die',
#   'car',
#   'cancer',
#   'old',
#   'age',
#   'sleep',
#   'death',
#   'certificate',
#   'need',
#   'blow'],
#  ['like', 'hoax', 'like', 'hoax', 'like', 'hoax', 's'],
#  ['co', 'guess', 'u', 'trump'],
#  ['corona', 'flu', 'virus', 'similar', 'impact', 'normal', 'corona', 'need'],
#  ['flu',
#   'can',
#   'corona',
#   'different',
#   'corona',
#   'flu',
#   'justify',
#   'million',
#   'corona',
#   'just',
#   'one',
#   'year',
#   'flu'],
#  ['hoax',
#   'recovery',
#   'rate',
#   'need',
#   'fake',
#   'vaccine',
#   'even',
#   'go',
#   'ahead',
#   'queue',
#   'vaccine'],
#  ['trump', 'done'],
#  ['million', 'info', 'fox'],
#  ['recovery',
#   'dead',
#   't',
#   'mean',
#   'damage',
#   'also',
#   'force',
#   'risk',
#   'life',
#   'just',
#   'deal',
#   'average',
#   'risk'],
#  ['s',
#   'paranoid',
#   'trait',
#   'people',
#   'lean',
#   'conspiracy',
#   'see',
#   'huge',
#   'impact',
#   'virus',
#   'dramatic',
#   'enough',
#   'match'],
#  ['use',
#   'knowledge',
#   'truth',
#   'corona',
#   'virus',
#   'also',
#   'believe',
#   'mask',
#   'can',
#   'block',
#   'virus',
#   'safe',
#   'will',
#   'effect',
#   'keep',
#   'head',
#   'sand',
#   'follow',
#   'responsible',
#   'knowledge',
#   'will',
#   'carry',
#   'thereof'],
#  ['hoax',
#   'man',
#   'bloody',
#   'fake',
#   'media',
#   'plan',
#   'people',
#   'die',
#   'corona',
#   'still',
#   'one',
#   'need',
#   'yet',
#   'want',
#   'vaccine',
#   'save',
#   'life',
#   'friend',
#   'get',
#   'brain'],
#  ['health', 'due', 'old', 'age'],
#  ['good',
#   'idea',
#   'media',
#   'south',
#   'well',
#   'done',
#   'country',
#   'just',
#   'start',
#   'race',
#   'thing',
#   'boom',
#   'one',
#   'together',
#   'get',
#   'well',
#   'gas',
#   'fire',
#   'media',
#   'succeed',
#   'plan',
#   'fight',
#   'race'],
#  ['many', 'false', 'country', 'many'],
#  ['agree'],
#  ['virus',
#   'real',
#   'event',
#   'open',
#   'mind',
#   'decide',
#   'feel',
#   'safe',
#   'official',
#   'continue',
#   'path',
#   'however',
#   'smell',
#   'something',
#   'rotten',
#   'entire',
#   'pandemic',
#   'many',
#   'official',
#   'wrong',
#   'false'],
#  ['s', 'grandma', 'corona', 'go'],
#  ['hi',
#   'truly',
#   'sorry',
#   'loss',
#   'know',
#   'anything',
#   'corona',
#   'know',
#   'alone',
#   'virus',
#   'freedom',
#   'will',
#   'away',
#   'something',
#   'dangerous',
#   'normal',
#   'flu'],
#  [],
#  ['straight',
#   'pantry',
#   's',
#   'vaccine',
#   's',
#   's',
#   'country',
#   'origin',
#   's',
#   'reason',
#   'virus',
#   'joke',
#   'nowhere',
#   'near',
#   're',
#   'world',
#   'health',
#   'us',
#   'claim',
#   'rate',
#   'zero',
#   'point',
#   'three',
#   'e',
#   'thousand',
#   'people',
#   'hit',
#   'said',
#   'current',
#   'death',
#   'toll',
#   'million',
#   'last',
#   'year',
#   'million',
#   'people',
#   'common',
#   'cold'],
#  ['want', 'come', 'say', 'local', 'live', 'long', 'enough', 'get', 'admitted'],
#  ['proof', 're', 'fake', 'stupid'],
#  ['can', 'percentage', 'troll'],
#  ['answer',
#   's',
#   'always',
#   'say',
#   'something',
#   'ridiculous',
#   'state',
#   'fact',
#   'get',
#   'legitimacy',
#   'said',
#   'fact',
#   'tell',
#   'can',
#   't',
#   'provide',
#   'please',
#   'stop',
#   'info',
#   'don',
#   't',
#   'anything',
#   'false',
#   'information',
#   'believe',
#   'whatever',
#   'garbage',
#   'found',
#   'site'],
#  ['just',
#   'check',
#   'diagnostic',
#   'panel',
#   'last',
#   'paragraph',
#   'positive',
#   'check',
#   'bill',
#   'foundation',
#   'will',
#   'tell',
#   'vaccine',
#   'top',
#   'similar',
#   'technology',
#   'check',
#   'u',
#   'n',
#   'new',
#   'world',
#   'order',
#   'check',
#   'future',
#   'fun'],
#  ['know', 'work'],
#  ['radioactive',
#   'hey',
#   'make',
#   'mind',
#   'consume',
#   'information',
#   'will',
#   'post'],
#  ['information', 'reason', 'give', 'link'],
#  ['radioactive',
#   'ha',
#   'ha',
#   'think',
#   'village',
#   'idiot',
#   'cant',
#   'talk',
#   'talk',
#   'told',
#   'find',
#   'info',
#   'check',
#   'choice'],
#  ['even',
#   'similar',
#   'tech',
#   'bad',
#   'thing',
#   'fact',
#   'just',
#   'prove',
#   'vaccine'],
#  ['self', 'tech', 'must', 'insane'],
#  ['s', 'vaccine'],
#  ['watch', 'many', 'say', 'cheese'],
#  ['trust', 'vaccine', 'people', 'behind', 'fine', 'done'],
#  ['average', 'death', 'agree', 'point', 'recovery'],
#  ['people',
#   'now',
#   'difficulty',
#   'damage',
#   'dealt',
#   'lung',
#   'tissue',
#   'well',
#   'system'],
#  ['let', 'take', 'vaccine', 'first', 'give', 'us', 'see'],
#  ['wow', 're', 'comment', 'section', 'think', 'point', 'point'],
#  ['point', 'homework', 'vaccine', 'maybe', 'get'],
#  ['hate', 'break', 't'],
#  ['pass', 'life', 'science', 'school'],
#  ['sorry',
#   'science',
#   't',
#   'take',
#   'biology',
#   't',
#   'get',
#   'life',
#   's',
#   'price',
#   'pay',
#   's',
#   'worth',
#   'something'],
#  ['co', 'know', 'two'],
#  ['yeah', 'use', 'lung', 'tissue'],
#  ['co', 'can'],
#  ['science'],
#  ['straight', 'pantry', 'know', 'clump'],
#  ['co', 'wow', 'real', 'mature'],
#  ['co',
#   'wow',
#   't',
#   'cool',
#   'take',
#   'someone',
#   'science',
#   're',
#   'complete',
#   'utter',
#   'tool'],
#  ['m',
#   'one',
#   't',
#   's',
#   'complete',
#   'task',
# ...
#  [],
#  ['history'],
#  ['thought', 'thing', 'must', 'stand', 'firm', 'time'],
#  ['indeed',
#   'know',
#   'someone',
#   'final',
#   'solution',
#   'will',
#   'perish',
#   'stay',
#   'alert',
#   'stay',
#   'home',
#   'wait',
#   'mandatory',
#   'vaccine'],
#  ['take',
#   'pandemic',
#   'definition',
#   'just',
#   'big',
#   'money',
#   'racket',
#   'know',
#   'behind',
#   'wear',
#   'mask',
#   'proven',
#   'health',
#   'spread',
#   'truth',
#   'scam'],
#  ['fan',
#   'sorry',
#   'inform',
#   'people',
#   'can',
#   'make',
#   'knowledge',
#   'clue',
#   'yet',
#   'think',
#   'wow',
#   'hey',
#   'god',
#   'make',
#   'world',
#   'peaceful'],
#  ['soon',
#   'won',
#   't',
#   'allow',
#   'anyone',
#   'country',
#   'choose',
#   'spread',
#   'virus',
#   'instead',
#   'shot',
#   'sense',
#   'mandatory',
#   're'],
#  ['beth'],
#  ['well'],
#  ['c',
#   'w',
#   'said',
#   't',
#   'us',
#   'also',
#   'rest',
#   'world',
#   'just',
#   'test',
#   'someone',
#   'one',
#   'free'],
#  ['c', 'w', 'also'],
#  ['go', 'first'],
#  ['work', 'period', 'south', 'take', 'stop', 'propaganda'],
#  ['like', 'b', 'hook'],
#  ['must', 'stop', 'country', 'apart'],
#  ['care', 'people'],
#  ['see', 'vaccine'],
#  ['one', 'tachyon', 'smallpox'],
#  ['black', 'live', 'now', 'us'],
#  ['spirit', 'warrior', 'enemy', 's', 'intellectual', 'battle', 'now'],
#  ['spirit', 'warrior', 'black', 'care', 'black'],
#  ['said',
#   'people',
#   'vaccine',
#   'bill',
#   'already',
#   'patent',
#   'vaccine',
#   'patent',
#   'wish',
#   'lying',
#   'look'],
#  ['summary',
#   'don',
#   't',
#   'know',
#   'mark',
#   'anything',
#   'even',
#   'similar',
#   'vaccine',
#   'vaccine',
#   'nothing',
#   'except',
#   'protect',
#   'people',
#   'just',
#   'occurring',
#   'enzyme',
#   'useful',
#   'function',
#   'various',
#   'nothing',
#   'nefarious',
#   'body',
#   'data',
#   'vaccine',
#   'nothing',
#   'trade',
#   'patent',
#   'arbitrary',
#   'conspiratorial',
#   'ridiculous',
#   'part',
#   'entire',
#   'message',
#   's',
#   'lot'],
#  ['lewis', 'stop', 'people'],
#  ['lewis', 'take', 'people'],
#  ['bless',
#   'prove',
#   'm',
#   'incorrect',
#   'get',
#   'call',
#   'deceitful',
#   'otherwise',
#   're',
#   'm',
#   'wrong',
#   'without',
#   'deceitful',
#   'oh',
#   'irony'],
#  ['word',
#   'seed',
#   'take',
#   'people',
#   'proof',
#   're',
#   'solid',
#   'support',
#   're',
#   'welcome',
#   'bring',
#   'shall',
#   'discuss',
#   'can',
#   're',
#   'just',
#   'another',
#   'conspiratorial',
#   'hack'],
#  [],
#  ['lying', 'long', 'time', 'already'],
#  ['thank', 'people', 'volunteer'],
#  ['s',
#   'u',
#   'comment',
#   'haven',
#   't',
#   'loose',
#   'yet',
#   'corona',
#   'virus',
#   'keep',
#   'lie',
#   'u',
#   'will',
#   'cry'],
#  ['awake'],
#  ['amen', 'wish', 'everyone', 'awake'],
#  ['allow',
#   'vaccine',
#   'agenda',
#   'never',
#   'stop',
#   'future',
#   'will',
#   'dangerous',
#   'one',
#   'wake'],
#  ['woke',
#   'stay',
#   'claim',
#   'will',
#   'dangerous',
#   'future',
#   'conjecture',
#   'best',
#   'contrary',
#   'will',
#   'technology',
#   'science',
#   'general',
#   'forward',
#   're',
#   'anti'],
#  ['bill', 'behind', 'pause', 'will', 'bill', 'foundation'],
#  [],
#  [],
#  ['bill', 'new', 'world', 'order', 'said', 'test', 'vaccine', 'people'],
#  ['protest',
#   'protestation',
#   'work',
#   'wonderland',
#   'start',
#   'rest',
#   'class',
#   'will',
#   'follow',
#   'just',
#   'like',
#   'busy',
#   'think',
#   'effect',
#   'dirty',
#   'plan',
#   'don',
#   't',
#   'think',
#   'busy',
#   'night',
#   'demoniac',
#   'get',
#   's',
#   'work',
#   'done',
#   'satan',
#   'took',
#   'hill',
#   'told',
#   'bow',
#   'worship',
#   'give',
#   'thus',
#   'lord',
#   'knew',
#   'one',
#   'fall',
#   'heir',
#   'way',
#   'satan',
#   'give',
#   'don',
#   't',
#   'worry',
#   'god',
#   's',
#   'wrath',
#   'fall',
#   'world',
#   'never',
#   'escape',
#   'satan'],
#  ['vaccine', 'good', 'watch', 'space'],
#  ['whole', 'thing'],
#  ['want'],
#  [],
#  ['s',
#   'good',
#   'don',
#   't',
#   'take',
#   'vaccine',
#   's',
#   'cause',
#   'trouble',
#   'bill',
#   'behind',
#   'pause',
#   'will',
#   'bill',
#   'foundation',
#   'trial',
#   'section'],
#  ['u', 'serious', 'mark', 'beast', 'book', 'revelation'],
#  ['just',
#   'pause',
#   'will',
#   'see',
#   'bill',
#   'foundation',
#   'trial',
#   'section',
#   'vaccine',
#   'good',
#   'don',
#   't',
#   'take',
#   'vaccine'],
#  ['pause', 'will', 'see', 'bill', 'foundation', 'trial', 'section'],
#  ['lord', 'glad', 'south', 'awake', 'amen'],
#  ['u',
#   'u',
#   'know',
#   'put',
#   'vaccine',
#   'mess',
#   'brain',
#   'body',
#   'u',
#   'need',
#   'nothing'],
#  ['money', 'worth', 'life', 'use', 'money', 'will', 'vaccine', 'kill'],
#  ['lewis', 'spoken', 'someone', 'access'],
#  ['sold', 'us'],
#  ['s', 's', 'country', 'people', 'attitude', 'like'],
#  ['cat',
#   'u',
#   'u',
#   'bill',
#   'vaccine',
#   'close',
#   'u',
#   'bill',
#   'since',
#   'birth',
#   'rate',
#   'drug',
#   'mess',
#   'egg',
#   'produce',
#   'u',
#   'stop',
#   'stupid',
#   'idiot',
#   'time'],
#  ['claim',
#   'false',
#   'vaccine',
#   'bill',
#   'gave',
#   'human',
#   'got',
#   'sick',
#   'polio',
#   'vaccine',
#   'awful',
#   'woman'],
#  ['seen',
#   'first',
#   'class',
#   'people',
#   'put',
#   'south',
#   'vulnerable',
#   'hope',
#   'protect',
#   'final',
#   'vaccine',
#   'already',
#   'distinct',
#   'group',
#   'tend',
#   'perform',
#   'thus',
#   'important',
#   'well',
#   'trial',
#   'final',
#   'vaccine',
#   'will',
#   'perform',
#   'well',
#   'region'],
#  [],
#  ['sold', 'thank', 'bill', 'foundation'],
#  ['bless', 'heart', 'need', 'something', 'sell', 's'],
#  ['course',
#   'everything',
#   'bill',
#   'virus',
#   'mark',
#   'beast',
#   'vaccine',
#   'digital',
#   'tattoo',
#   'new',
#   'world',
#   'order'],
#  ['lewis', 'able', 'back', 'claim', 'solid'],
#  ['s', 'wrong'],
#  ['u',
#   'can',
#   't',
#   'see',
#   'wrong',
#   'maybe',
#   'u',
#   'volunteer',
#   'take',
#   'vaccine'],
#  ['money',
#   'scam',
#   'bill',
#   'big',
#   'use',
#   'poor',
#   'black',
#   'people',
#   'care',
#   'well',
#   'cook',
#   'data',
#   'inform',
#   'must',
#   'stop',
#   'abuse'],
#  ['don', 't'],
#  ['pray', 'lost', 'mark', 'beast', 'take', 'vaccine'],
#  ['lewis', 'vaccine', 'job', 'protect', 'people', 's', 'mark', 'anything'],
#  ['lewis',
#   'feel',
#   'pain',
#   'people',
#   'lost',
#   'anyway',
#   'say',
#   'message',
#   'like',
#   'sheep',
#   'wake',
#   'human',
#   'beg',
#   'name',
#   'wake',
#   'hour',
#   'wake',
#   'people',
#   'world',
#   'u',
#   'think'],
#  ['won',
#   't',
#   'heal',
#   'anyone',
#   's',
#   'cause',
#   'death',
#   'bill',
#   'behind',
#   'vaccine',
#   'pause',
#   'will',
#   'see',
#   'bill',
#   'foundation',
#   'trial',
#   'section'],
#  ['don',
#   't',
#   'take',
#   'vaccine',
#   's',
#   'cause',
#   'trouble',
#   'bill',
#   'behind',
#   'pause',
#   'will',
#   'bill',
#   'foundation',
#   'trial',
#   'section'],
#  ['death'],
#  ['amen', 'agree', 'fully', 'god', 'help', 'us'],
#  [],
#  ['like',
#   'know',
#   'type',
#   'stuff',
#   'doctor',
#   'put',
#   'vaccine',
#   'made',
#   'vaccine'],
#  ['please', 'reed', 'story', 'kind'],
#  ['don',
#   't',
#   'take',
#   'vaccine',
#   's',
#   'cause',
#   'trouble',
#   'bill',
#   'behind',
#   'pause',
#   'will',
#   'see',
#   'bill',
#   'foundation',
#   'trial',
#   'section'],
#  ['true'],
#  ['everything',
#   'said',
#   'truth',
#   'vaccine',
#   'patent',
#   'similar',
#   'satan',
#   's',
#   'blind',
#   'sheep',
#   'wake',
#   'fast',
#   's'],
#  ['lewis',
#   'satan',
#   's',
#   'want',
#   'see',
#   'series',
#   'satan',
#   's',
#   'can',
#   'just',
#   'imagine',
#   'script',
#   'satan',
#   'life',
#   'full',
#   'long',
#   'beach'],
#  ['course'],
#  ['u', 'can', 'see'],
#  ['paid', 'breach', 'since', 'study', 'people'],
#  ['supply', 'please'],
#  ['lewis',
#   'see',
#   't',
#   'know',
#   't',
#   'poor',
#   'guy',
#   'trial',
#   'spoke',
#   'said',
#   'gave',
#   'always',
#   'incentive',
#   'evil',
#   'people',
#   'get',
#   'poor',
#   'state',
#   're',
#   'paid',
#   'lab'],
#  ['issue',
#   'pandemic',
#   'people',
#   'embrace',
#   'lie',
#   'can',
#   'embrace',
#   'also',
#   'behind'],
#  ['s',
#   'hoax',
#   'agenda',
#   'go',
#   'collapse',
#   'economy',
#   'one',
#   'world',
#   'religion',
#   'one',
#   'world',
#   'economy',
#   'bill',
#   'hell',
#   'include',
#   'device',
#   'finance',
#   'personal',
#   'information',
#   'inside',
#   'digital',
#   'mark',
#   'tattoo',
#   'one',
#   'world'],
#  ['name'],
#  ['us', 'show', 'us', 'scripture', 's', 'got'],
#  ['support',
#   'just',
#   'don',
#   't',
#   'know',
#   'will',
#   'play',
#   'sure',
#   'agenda',
#   'go',
#   'collapse',
#   'economy',
#   'one',
#   'world',
#   'religion',
#   'one',
#   'world',
#   'economy',
#   'bill',
#   'hell',
#   'include',
#   'device',
#   'finance',
#   'personal',
#   'information',
#   'inside',
#   'digital',
#   'mark',
#   'tattoo',
#   'one',
#   'world'],
#  ['read'],
#  ['correct', 'people', 'need', 'fight', 'common', 'cold', 'vaccine'],
#  ['people',
#   'read',
#   's',
#   'various',
#   'scientific',
#   'educate',
#   'either',
#   'ignorant',
#   'agenda',
#   'new',
#   'pass',
#   'put',
#   'mankind',
#   'century',
#   'bill',
#   'got',
#   'world',
#   'read',
#   'family',
#   'history',
#   'next',
#   'step',
#   'mankind',
#   'suit',
#   'local',
#   'agenda',
#   'still',
#   'reconcile',
#   'whole',
#   'economy',
#   'science',
#   'death',
#   'even',
#   'become',
#   'social',
#   'prepare',
#   'us',
#   'tech',
#   'can',
#   'track',
#   'feel',
#   'sorry',
#   'junta',
#   'can',
#   'go',
#   'restaurant',
#   'want',
#   'must',
#   'sit',
#   'mask',
#   'give',
#   'us',
#   'break',
#   's',
#   'will',
#   'go',
#   'bankrupt',
#   'get',
#   'brought',
#   'end'],
#  ['look',
#   'history',
#   'cure',
#   'since',
#   'selfish',
#   'see',
#   'herb',
#   'many',
#   'west',
#   'help',
#   'already',
#   'medicine',
#   'nature'],
#  ['either',
#   'troll',
#   'ignorant',
#   'force',
#   'new',
#   'pass',
#   'law',
#   'now',
#   'military',
#   'military',
#   'arrest',
#   'go',
#   'beach',
#   'can',
#   'cripple',
#   'economy',
#   'get',
#   'one',
#   'wonder',
#   'agenda'],
#  ['need', 'loosen', 'tinfoil', 'hat', 'buddy', 's', 'head', 'bit', 'much'],
#  ['re',
#   'paid',
#   'breach',
#   'since',
#   'financial',
#   'incentive',
#   'trial',
#   'people'],
#  ['true'],
#  ['please', 'reed', 'story', 'kind'],
#  ['mean',
#   'people',
#   'don',
#   't',
#   'even',
#   'vaccine',
#   'will',
#   'bring',
#   'trouble',
#   'aware',
#   'bill',
#   'ran'],
#  ['proven',
#   'play',
#   'beneficial',
#   'role',
#   'corona',
#   'let',
#   'alone',
#   'cure',
#   'fact',
#   's',
#   'potential',
#   'harmful',
#   'know'],
#  ['lewis',
#   'sorry',
#   'false',
#   'credible',
#   'top',
#   'lancet',
#   'also',
#   'false',
#   'work',
#   'etc',
#   'rather',
#   'push',
#   'choice',
#   'rather',
#   'pill',
#   'influenza',
#   'check',
#   's',
#   'big',
#   'tree',
#   'numerous',
#   'truth',
#   's',
#   'show',
#   'real',
#   'truth',
#   'part',
#   'deep',
#   'state',
#   'dose',
#   'must',
#   'patient',
#   'patient',
#   'late',
#   'administer',
#   'work'],
#  ['oh', 'husband', 'wife', 'ready', 'many', 'truth', 'amp', 'fact'],
#  ['haven',
#   't',
#   'able',
#   'substantiate',
#   'actual',
#   'scientific',
#   'fact',
#   'efficacy',
#   'numerous',
#   'credible',
#   'benefit',
#   'possible',
#   'harmful',
#   'read',
#   'room',
#   'q',
#   'detail',
#   'q',
#   'text',
#   'although',
#   'moment',
#   'start',
#   'deep',
#   'state',
#   'know',
#   'fallen',
#   'seductive',
#   'lean',
#   'vague',
#   'nefarious',
#   'instead'],
#  ['whether',
#   'two',
#   't',
#   'prove',
#   're',
#   'together',
#   'numerous',
#   'rickety',
#   'web',
#   'draw',
#   'massive',
#   'said',
#   'done',
#   'still',
#   'wave',
#   'air',
#   'proclaim',
#   'connect',
#   'use',
#   'evaluate',
#   'truth',
#   'behind',
#   'claim',
#   'single',
#   'concrete',
#   'fact',
#   'put',
#   'together',
#   'bring',
#   'concrete',
#   'scientific',
#   'scientific',
#   'scrutiny',
#   'can',
#   'talk'],
#  ['lewis',
#   'go',
#   'given',
#   'real',
#   'truth',
#   'conspiracy',
#   'tribunal',
#   'natural',
#   'justice',
#   'real',
#   's',
#   'throughout',
#   'world',
#   'success',
#   'use',
#   'malaria',
#   'take',
#   'park',
#   'doctor',
#   'successful',
#   'vaccine',
#   'lethal',
#   'never',
#   'since',
#   's',
#   'just',
#   'appear',
#   'magic',
#   'unicorn',
#   'many',
#   'many',
#   's',
#   'now',
#   'south',
#   'will',
#   'wake',
#   'trickery'],
#  ['dear',
#   'real',
#   'doctor',
#   'two',
#   'someone',
#   'whose',
#   'entire',
#   'profession',
#   'best',
#   'current',
#   'wrong',
#   'every',
#   'single',
#   'person',
#   'none',
#   'able',
#   'substantiate',
#   'actual',
#   'scientific',
#   's',
#   'real',
#   'scientist',
#   'doctor'],
#  ['lewis',
#   'well',
#   'seeing',
#   'quite',
#   'lying',
#   'us',
#   's',
#   'court',
#   'offer',
#   'doctor',
#   'therefore',
#   'rather',
#   's',
#   'vaccine',
#   'onto',
#   'sa',
#   'onto',
#   'made',
#   'money',
#   'along',
#   'big',
#   'support',
#   'tablet',
#   'jab',
#   'skin',
#   'confuse',
#   'immune',
#   'system',
#   'sir',
#   'taken',
#   'away',
#   'wonder',
#   's',
#   'conjecture',
#   'doctor',
#   's',
#   'direct',
#   'whistle',
#   'tell',
#   'doctor',
#   'guess',
#   'make',
#   'money',
#   'sick',
#   'different',
#   'jab',
#   'one',
#   'fix',
#   'don',
#   't',
#   'think',
#   'hey'],
#  ['please',
#   'provide',
#   'credible',
#   'proven',
#   'may',
#   'lie',
#   't',
#   'don',
#   't',
#   'doubt',
#   're',
#   'focus',
#   'onto',
#   'rather',
#   'scientific',
#   'list',
#   'vaccine',
#   'nothing',
#   'list',
#   'body',
#   'nothing',
#   'safety',
#   'oral',
#   'tablet',
#   'fine',
#   't',
#   'claim',
#   'please',
#   'cite',
#   'bring',
#   'claim',
#   'fail',
#   're',
#   'air',
#   'draw',
#   'grandiose',
#   'conclusion',
#   'two',
#   'separate',
#   'without',
#   'prove',
#   'injustice',
#   'nefarious',
#   'intention',
#   'grandiose',
#   'require',
#   'grandiose',
#   'm',
#   'behalf',
#   'health',
#   'south',
#   'die',
#   'm',
#   'use',
#   'blatant',
#   'jargon',
#   'flashy',
#   'convince',
#   'don',
#   't',
#   'know',
#   'make',
#   'affect',
#   'health',
#   'way',
#   's',
#   'health',
#   'whole',
#   's',
#   'vaccine'],
#  ['safe',
#   'refer',
#   's',
#   'many',
#   'scientific',
#   'even',
#   'scientific',
#   'study',
#   'meet',
#   'etc',
#   'people',
#   'planet',
#   'wake',
#   'attack',
#   'take',
#   'us',
#   'back',
#   'servitude'],
#  ['y',
#   'can',
#   't',
#   'think',
#   'safe',
#   'use',
#   'don',
#   't',
#   'know',
#   'test',
#   'people',
#   's',
#   'like',
#   'said'],
#  [],
#  ['e',
#   'make',
#   'vaccine',
#   'corona',
#   'part',
#   'evolve',
#   'bacteria',
#   'around',
#   'check',
#   'produce',
#   'corona',
#   'evil',
#   'like',
#   'went',
#   'ahead',
#   'm',
#   'sure',
#   's',
#   'influenza',
#   'around',
#   'roof',
#   't',
#   'work',
#   'faith',
#   'natural',
#   'immune',
#   'system',
#   'natural',
#   'vaccine',
#   'yet',
#   's',
#   'push',
#   'take',
#   'keep',
#   'us',
#   'sick',
#   'see',
#   'video',
#   's',
#   'air',
#   'create',
#   'immune',
#   'need',
#   'around',
#   'us',
#   'build',
#   'immune',
#   'check',
#   'brilliant',
#   'testimony',
#   'tribunal',
#   'natural',
#   'justice',
#   'vaccine',
#   'story',
#   'want',
#   'safe',
#   'can',
#   'one',
#   'mercury',
#   'round',
#   'animal',
#   'tissue',
#   'fetus',
#   'tissue',
#   'rest',
#   'bad',
#   'know',
#   'will',
#   'kill',
#   'make',
#   'sick',
#   'big',
#   'see'],
#  ['polio',
#   'part',
#   'polio',
#   'vaccine',
#   'standard',
#   'vaccine',
#   'schedule',
#   'almost',
#   'everyone',
#   'born',
#   'country',
#   'lucky',
#   'enough',
#   'one',
#   'just',
#   'something',
#   'part',
#   'make',
#   'benign',
#   'b',
#   'make',
#   'immune',
#   'need',
#   'c',
#   'make',
#   'vaccine',
#   'part',
#   'm',
#   'pretty',
#   'sure',
#   't',
#   'healthy',
#   'diet',
#   'immune',
#   'system',
#   'need',
#   'protect',
#   'vaccine',
#   'able',
#   's',
#   'best',
#   'across',
#   'world',
#   'accelerate',
#   'process',
#   'much',
#   'success',
#   'normal',
#   'vaccine',
#   'can',
#   'see',
#   'still',
#   's',
#   'sa',
#   'trial',
#   'part'],
#  ['lewis',
#   'look',
#   'polio',
#   'vaccine',
#   'real',
#   'truth',
#   'many',
#   'go',
#   'vaccine',
#   'story',
#   'still',
#   'try',
#   'watch',
#   'movie',
#   'm',
#   'sure',
#   'taken',
#   'various'],
#  ['share', 'please'],
#  ['still'],
#  ['problem',
#   'us',
#   'sa',
#   'always',
#   'choose',
#   'trust',
#   'wrong',
#   'people',
#   'business',
#   'man',
#   'people'],
#  ['normal', 'soon', 'will', 'say', 'will', 'follow'],
#  ['make'],
#  ['vaccine', 'trial', 's', 'best', 'country'],
#  ['van',
#   'time',
#   'm',
#   'next',
#   'never',
#   'entire',
#   'life',
#   'sure',
#   'know',
#   'vote'],
#  ['simply',
#   'carol',
#   'will',
#   'okay',
#   'use',
#   'time',
#   'heal',
#   'mind',
#   'soul',
#   'learn',
#   'truth',
#   'alone',
#   'fight',
#   'many',
#   'section',
#   'right',
#   'now',
#   'afraid',
#   'express',
#   'fear',
#   'please',
#   'know',
#   'hear',
#   'never',
#   'wish',
#   'made',
#   'process',
#   'way',
#   'love',
#   'compassion',
#   'will',
#   'cure',
#   'truth',
#   'common',
#   'crazy',
#   'simply',
#   'exposure',
#   'truth',
#   'imminent',
#   'now',
#   'know',
#   'god'],
#  ['van', 'say', 'hope', 'say', 'vote', 'white', 'party', 'like'],
#  ['simply', 'carol', 'far', 'topic'],
#  ['d', 'care', 'money', 'people'],
#  ['blaze'],
#  ...]

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# UNIT TEST COMMENT: Candidate for Table Driven Tests
# GRADED FUNCTION: get_count
def get_count(word_l):
    '''
    Input:
        word_l: a set of words representing the corpus. 
    Output:
        word_count_dict: The wordcount dictionary where key is the word and value is its frequency.
    '''
    
    word_count_dict = {}  # fill this with word counts
    ### START CODE HERE 
    word_count_dict.update(Counter(word_l))
            
    ### END CODE HERE ### 
    return word_count_dict

# %%
#Going over all sentences to get word counts and create word frequencies
# Depends on get_count function
def corpus_word_count(sentences):
    full_count_comments = {}
    for i in range(len(sentences)):
        full_count_comments.update(get_count(sentences[i]))
    return full_count_comments
#full_count

# %%
replies_word_counts = corpus_word_count(cleaned_reply_tokens)
comments_word_counts = corpus_word_count(cleaned_comment_tokens)

# %%
comments_word_counts
# Out:
# {'please': 1,
#  'come': 1,
#  'cure': 1,
#  'cancer': 1,
#  'want': 1,
#  'give': 1,
#  'testimonial': 1,
#  'virus': 1,
#  'ago': 1,
#  'went': 1,
#  'see': 1,
#  'doctor': 1,
#  'lot': 1,
#  'blood': 1,
#  'later': 1,
#  'told': 1,
#  'felt': 1,
#  'bad': 1,
#  'possible': 1,
#  'saw': 1,
#  'post': 1,
#  'someone': 1,
#  'said': 1,
#  'medicine': 1,
#  'can': 1,
#  'heal': 1,
#  'sent': 1,
#  'courier': 1,
#  'took': 2,
#  'another': 1,
#  'test': 1,
#  'also': 2,
#  'get': 1,
#  'help': 1,
#  'hepatitis': 1,
#  'b': 1,
#  'lateral': 1,
#  'sclerosis': 1,
#  'genital': 1,
#  'simple': 2,
#  'herpes': 1,
#  'diabetes': 1,
#  'sickle': 1,
#  'etc': 1,
#  'penis': 1,
#  'broken': 1,
#  'contact': 1,
#  'sleepy': 1,
#  'vaccine': 1,
#  'new': 1,
#  'type': 1,
#  's': 1,
#  'mandatory': 2,
#  'take': 2,
#  'flu': 1,
#  'every': 1,
#  'kid': 1,
#  'bill': 1,
#  'million': 1,
#  'lure': 1,
#  'third': 1,
#  'world': 1,
#  'think': 1,
#  'trial': 1,
#  'work': 1,
#  'watch': 1,
#  'v': 6,
#  't': 1,
#  'hide': 1,
#  'sheer': 1,
#  'delight': 1,
#  'people': 1,
#  'ass': 1,
#  'evil': 1,
#  'never': 1,
#  'god': 1,
#  'immune': 1,
#  'system': 1,
#  'destroy': 1,
#  'soul': 1,
#  'gone': 1,
#  'feel': 1,
#  'zombie': 1,
#  'apocalypse': 1,
#  'away': 1,
#  'will': 1,
#  'knew': 1,
#  'call': 2,
#  'reason': 1,
#  'brain': 1,
#  'barrier': 1,
#  'death': 1,
#  'mass': 1,
#  'click': 1,
#  'like': 1,
#  'bless': 1,
#  'protect': 1,
#  'share': 1,
#  'worst': 1,
#  'seen': 1,
#  'know': 1,
#  'one': 1,
#  'south': 1,
#  'lab': 1,
#  'pay': 1,
#  'crime': 1,
#  'professor': 1,
#  'agent': 1,
#  'satan': 1,
#  'burn': 1,
#  'hell': 1,
#  'let': 1,
#  'whole': 1,
#  'diagnose': 1,
#  'hope': 1,
#  'lost': 1,
#  'nothing': 1,
#  'just': 1,
#  'faith': 1,
#  'day': 1,
#  'pray': 1,
#  'everyday': 1,
#  'sister': 4,
#  'introduce': 1,
#  'man': 1,
#  'well': 1,
#  'gave': 1,
#  'try': 1,
#  'fully': 1,
#  'ask': 1,
#  'two': 2,
#  'different': 1,
#  'today': 1,
#  'medium': 1,
#  'bacterial': 1,
#  'rest': 1,
#  'name': 1,
#  'polio': 1,
#  'end': 1,
#  'don': 1,
#  'need': 2,
#  'crap': 1,
#  'fight': 2,
#  'yet': 1,
#  'year': 1,
#  'point': 1,
#  'wonder': 1,
#  'black': 1,
#  'now': 1,
#  'almost': 1,
#  'continent': 2,
#  'guinea': 1,
#  'elite': 1,
#  'corrupt': 1,
#  'soon': 1,
#  'ready': 2,
#  'time': 1,
#  'short': 1,
#  'delay': 1,
#  'make': 1,
#  'right': 1,
#  'still': 1,
#  'left': 1,
#  'behind': 1,
#  'stop': 1,
#  'vaccinate': 1,
#  'real': 1,
#  'movie': 1,
#  'put': 1,
#  'life': 1,
#  'study': 1,
#  'happy': 1,
#  'smokescreen': 1,
#  'particular': 1,
#  'already': 1,
#  'long': 1,
#  'agenda': 2,
#  'compassionate': 1,
#  'use': 1,
#  'severe': 1,
#  'standard': 1,
#  'care': 1,
#  'low': 1,
#  'dose': 1,
#  'anti': 1,
#  'human': 1,
#  'clear': 1,
#  'safety': 2,
#  'profile': 1,
#  'content': 1,
#  'full': 1,
#  'l': 1,
#  'o': 1,
#  'kill': 1,
#  'modify': 1,
#  'structure': 1,
#  'say': 1,
#  'many': 1,
#  'danger': 1,
#  'goal': 1,
#  'reduce': 1,
#  'satanic': 1,
#  'money': 1,
#  'scam': 1,
#  'pandemic': 1,
#  'sa': 1,
#  'three': 1,
#  'chance': 1,
#  'dying': 1,
#  'shove': 1,
#  'truth': 1,
#  're': 1,
#  'hello': 1,
#  'testify': 1,
#  'notorious': 1,
#  'serious': 1,
#  'ex': 1,
#  'husband': 1,
#  'meant': 1,
#  'great': 1,
#  'moment': 1,
#  'thing': 1,
#  'done': 1,
#  'typhoid': 1,
#  'fever': 1,
#  'good': 1,
#  'everyone': 1,
#  'go': 1,
#  'educate': 1,
#  'wont': 1,
#  'tell': 1,
#  'question': 1,
#  'hate': 1,
#  'plague': 1,
#  'exist': 2,
#  'die': 1,
#  'heart': 1,
#  'rush': 1,
#  'develop': 1,
#  'anything': 1,
#  'farce': 1,
#  'actual': 1,
#  'percent': 1,
#  'sure': 1,
#  'something': 1,
#  'around': 1,
#  'anybody': 1,
#  'shoot': 2,
#  'w': 1,
#  'h': 1,
#  'friend': 1,
#  'enemy': 1,
#  'cause': 1,
#  'body': 2,
#  'double': 1,
#  'talk': 1,
#  'idea': 1,
#  'allow': 1,
#  'selves': 2,
#  'sick': 1,
#  'contagious': 1,
#  'play': 1,
#  'game': 1,
#  'head': 1,
#  'justify': 1,
#  'plus': 1,
#  'cant': 1,
#  'first': 1,
#  'u': 1,
#  'fake': 1,
#  'even': 1,
#  'video': 1,
#  'much': 1,
#  'entire': 1,
#  'family': 1,
#  'successful': 1,
#  'anyone': 1,
#  'else': 1,
#  'otherwise': 1,
#  'wait': 1,
#  'satisfy': 1,
#  'success': 1,
#  'invention': 1,
#  'lesson': 1,
#  'ahead': 1,
#  'poison': 1,
#  'aware': 1,
#  'leave': 2,
#  'alone': 1,
#  'rather': 1,
#  'accept': 1,
#  'country': 1,
#  'vulnerable': 1,
#  'high': 1,
#  'racial': 1,
#  'level': 1,
#  'slavery': 1,
#  'control': 1,
#  'manipulate': 1,
#  'financial': 1,
#  'gain': 1,
#  'poor': 1,
#  'health': 1,
#  'nutrition': 3,
#  'part': 1,
#  'won': 1,
#  'less': 1,
#  'fortunate': 1,
#  'behalf': 1,
#  'shut': 1,
#  'best': 1,
#  'interest': 1,
#  'look': 1,
#  'china': 1,
#  'support': 1,
#  'puppet': 1,
#  'wake': 1,
#  'check': 1,
#  'lethal': 1,
#  'alert': 1,
#  'turn': 1,
#  'spike': 3,
#  'protein': 5,
#  'genetic': 2,
#  'material': 2,
#  'risk': 1,
#  'response': 1,
#  'produce': 1,
#  'feedback': 1,
#  'loop': 1,
#  'switch': 1,
#  'proof': 1,
#  'transcription': 1,
#  'viral': 1,
#  'must': 1,
#  'specific': 1,
#  'native': 1,
#  'synthesis': 1,
#  'risky': 1,
#  'us': 2,
#  'm': 1,
#  'harm': 1,
#  'oh': 1,
#  'next': 2,
#  'pacific': 1,
#  'rip': 1,
#  'rubbish': 1,
#  'love': 2,
#  'sit': 1,
#  'foundation': 1,
#  'board': 1,
#  'lie': 1,
#  'fir': 1,
#  'company': 1,
#  'thought': 1,
#  'shame': 1,
#  'ah': 1,
#  'start': 1,
#  'president': 1,
#  'remote': 1,
#  'white': 1,
#  'rid': 1,
#  'back': 2,
#  'child': 1,
#  'autism': 1,
#  'become': 1,
#  'earth': 3,
#  'mother': 1,
#  'spirit': 2,
#  'dear': 1,
#  'fire': 1,
#  'r': 1,
#  'bet': 1,
#  'none': 1,
#  'self': 1,
#  'arrest': 1,
#  'sold': 1,
#  'guy': 2,
#  'paid': 2,
#  'fear': 1,
#  'last': 1,
#  'hour': 1,
#  'found': 2,
#  'law': 2,
#  'dead': 1,
#  'bacteria': 1,
#  'form': 1,
#  'patient': 1,
#  'thrombosis': 2,
#  'way': 1,
#  'combat': 1,
#  'aspirin': 3,
#  'intensive': 1,
#  'unit': 1,
#  'therefore': 1,
#  'change': 1,
#  'began': 1,
#  'global': 1,
#  'business': 1,
#  'source': 2,
#  'ministry': 3,
#  'eye': 1,
#  'pass': 1,
#  'general': 1,
#  'contract': 1,
#  'made': 1,
#  'believe': 1,
#  'bacterium': 1,
#  'inflammation': 1,
#  'shown': 1,
#  'clot': 1,
#  'person': 1,
#  'flow': 1,
#  'oxygenate': 1,
#  'due': 1,
#  'able': 1,
#  'breathe': 1,
#  'protocol': 1,
#  'autopsy': 2,
#  'corpse': 1,
#  'cut': 1,
#  'oxygen': 1,
#  'diagnosis': 1,
#  'administer': 1,
#  'positive': 1,
#  'result': 1,
#  'home': 1,
#  'single': 1,
#  'urgent': 1,
#  'transmit': 1,
#  'information': 1,
#  'data': 1,
#  'save': 1,
#  'broke': 1,
#  'norm': 1,
#  'chaos': 1,
#  'worldwide': 1,
#  'collapse': 1,
#  'order': 1,
#  'incinerate': 1,
#  'bury': 1,
#  'without': 1,
#  'carry': 1,
#  'spread': 1,
#  'gel': 1,
#  'chlorine': 1,
#  'dioxide': 1,
#  'kick': 1,
#  'assassinate': 1,
#  'claim': 1,
#  'rate': 1,
#  'vs': 1,
#  'live': 1,
#  'host': 1,
#  'soccer': 1,
#  'alive': 1,
#  'stay': 1,
#  'stupid': 1,
#  'came': 1,
#  'wrong': 1,
#  'answer': 1,
#  'amp': 1,
#  'deep': 1,
#  'purge': 1,
#  'straight': 1,
#  'dare': 1,
#  'always': 1,
#  'welcome': 1,
#  'mat': 1,
#  'treat': 1,
#  'idiot': 1,
#  'war': 2,
#  'greedy': 1,
#  'hungry': 1,
#  'backward': 1,
#  'sell': 1,
#  'west': 1,
#  'true': 1,
#  'memory': 1,
#  'past': 1,
#  'forgotten': 1,
#  'keep': 1,
#  'endure': 1,
#  'kind': 1,
#  'enhance': 1,
#  'assess': 1,
#  'potential': 1,
#  'problem': 1,
#  'assure': 1,
#  'happen': 1,
#  'front': 1,
#  'month': 1,
#  'decide': 1,
#  'programmer': 1,
#  'software': 2,
#  'piece': 1,
#  'code': 1,
#  'everything': 1,
#  'fine': 1,
#  'expect': 1,
#  'install': 1,
#  'parliament': 1,
#  'lead': 1,
#  'push': 1,
#  'purpose': 1,
#  'biblical': 1,
#  'speak': 2,
#  'line': 1,
#  'natural': 1,
#  'group': 1,
#  'prison': 1,
#  'experiment': 1,
#  'mainstream': 1,
#  'dark': 1,
#  'growth': 1,
#  'individual': 1,
#  'touch': 2,
#  'aid': 1,
#  'fort': 1,
#  'secondary': 1,
#  'worse': 1,
#  'original': 1,
#  'story': 1,
#  'promote': 1,
#  'non': 1,
#  'convince': 1,
#  'mercury': 1,
#  'arsenic': 1,
#  'children': 1,
#  'propaganda': 1,
#  'horse': 1,
#  'motor': 3,
#  'car': 1,
#  'dung': 1,
#  'yea': 1,
#  'wild': 1,
#  'silver': 1,
#  'patent': 1,
#  'hear': 1,
#  'obsolete': 1,
#  'cheap': 1,
#  'smallpox': 2,
#  'machine': 1,
#  'proctor': 1,
#  'gamble': 1,
#  'product': 1,
#  'soap': 1,
#  'hygiene': 1,
#  'bubble': 1,
#  'municipal': 1,
#  'clean': 1,
#  'water': 7,
#  'common': 1,
#  'un': 1,
#  'heard': 1,
#  'bar': 1,
#  'seasonal': 1,
#  'asthma': 1,
#  'syndrome': 1,
#  'gulf': 1,
#  'mental': 1,
#  'leprosy': 1,
#  'multiple': 1,
#  'peanut': 1,
#  'misery': 1,
#  'insecticide': 1,
#  'malaria': 1,
#  'mosquito': 1,
#  'identify': 1,
#  'spray': 1,
#  'create': 1,
#  'excuse': 1,
#  'trust': 1,
#  'private': 1,
#  'extreme': 1,
#  'bottle': 1,
#  'plan': 1,
#  'old': 1,
#  'strategy': 1,
#  'fertile': 1,
#  'land': 3,
#  'depend': 1,
#  'food': 1,
#  'sugar': 1,
#  'either': 1,
#  'second': 1,
#  'wave': 1,
#  'young': 1,
#  'find': 1,
#  'procreate': 1,
#  'infertile': 1,
#  'controlling': 1,
#  'struggle': 1,
#  'birth': 1,
#  'future': 1,
#  'survival': 1,
#  'imbalance': 1,
#  'independent': 1,
#  'trap': 1,
#  'blind': 1,
#  'suck': 1,
#  'deceit': 1,
#  'goes': 1,
#  'exact': 1,
#  'opposite': 1,
#  'adequate': 1,
#  'access': 1,
#  'decision': 1,
#  'worry': 1,
#  'blame': 1,
#  'police': 1,
#  'military': 1,
#  'tear': 1,
#  'economic': 1,
#  'power': 1,
#  'exterminate': 1,
#  'choose': 1,
#  'side': 1,
#  'stand': 1,
#  'whistle': 1,
#  'butt': 1,
#  'suggestion': 1,
#  'career': 1,
#  'sense': 1,
#  'road': 1,
#  'proud': 1,
#  'big': 1,
#  'conspiracy': 1,
#  'sound': 1,
#  'far': 1,
#  'vitamin': 1,
#  'c': 1,
#  'science': 1,
#  'crazy': 1,
#  'huge': 1,
#  'innocent': 1,
#  'western': 1,
#  'deserve': 1,
#  'breath': 1,
#  'suffer': 1,
#  'may': 1,
#  'forever': 1,
#  'loss': 1,
#  'experience': 2,
#  'got': 1,
#  'media': 1,
#  'spell': 2,
#  'parent': 1,
#  'open': 1,
#  'late': 1,
#  'father': 1,
#  'article': 1,
#  'firefly': 1,
#  'learn': 1,
#  'mean': 1,
#  'issue': 1,
#  'headline': 1,
#  'begun': 2,
#  'condemn': 1,
#  'begin': 1,
#  'quit': 1,
#  'event': 1,
#  'greater': 1,
#  'place': 1,
#  'origin': 1,
#  'swear': 1,
#  'till': 1,
#  'since': 1,
#  'race': 2,
#  'wow': 1,
#  'despicable': 1,
#  'official': 1,
#  'bring': 2,
#  'together': 1,
#  'light': 1,
#  'documentary': 1,
#  'hidden': 1,
#  'safe': 1,
#  'truly': 1,
#  'ground': 1,
#  'beg': 1,
#  'dump': 1,
#  'approve': 1,
#  'gate': 1,
#  'involve': 1,
#  'fall': 1,
#  'sheet': 1,
#  'terrible': 1,
#  'director': 1,
#  'simply': 1,
#  'volunteer': 1,
#  'nobody': 1,
#  'though': 1,
#  'important': 1,
#  'heroes': 1,
#  'efficacy': 1,
#  'guarantee': 1,
#  'glass': 1,
#  'half': 1,
#  'empty': 1,
#  'cold': 1,
#  'rise': 1,
#  'maybe': 1,
#  'sign': 1,
#  'hey': 1,
#  'healthy': 5,
#  'hoax': 1,
#  'special': 1,
#  'epic': 1,
#  'loose': 1,
#  'job': 1,
#  'hold': 1,
#  'chip': 1,
#  'somebody': 1,
#  'liar': 1,
#  'read': 1,
#  'bit': 1,
#  'angry': 1,
#  'jab': 2,
#  'drug': 1,
#  'little': 1,
#  'team': 1,
#  'luck': 1,
#  'note': 1,
#  'require': 1,
#  'expert': 1,
#  'provide': 1,
#  'chest': 1,
#  'x': 1,
#  'ray': 1,
#  'mobile': 1,
#  'evaluate': 1,
#  'lung': 1,
#  'hesitate': 1,
#  'reach': 1,
#  'responsible': 1,
#  'affect': 1,
#  'listen': 1,
#  'unique': 1,
#  'percentage': 1,
#  'difficult': 1,
#  'history': 2,
#  'state': 1,
#  'grew': 1,
#  'fresh': 1,
#  'farm': 1,
#  'meat': 1,
#  'haven': 1,
#  'dangerous': 1,
#  'move': 1,
#  'brand': 1,
#  'pro': 1,
#  'irrelevant': 1,
#  'tonic': 1,
#  'isolate': 1,
#  'zoom': 2,
#  'session': 1,
#  'approval': 1,
#  'direct': 1,
#  'trail': 1,
#  'egg': 1,
#  'okay': 1,
#  'track': 1,
#  'yeah': 1,
#  'position': 1,
#  'survey': 1,
#  'solution': 1,
#  'freedom': 1,
#  'sacrifice': 1,
#  'expose': 1,
#  'n': 1,
#  'selfish': 1,
#  'snake': 1,
#  'oil': 1,
#  'salesmen': 1,
#  'field': 1,
#  'office': 1,
#  'rogue': 1,
#  'gospel': 2,
#  'fact': 1,
#  'roll': 1,
#  'pregnant': 1,
#  'women': 1,
#  'tech': 1,
#  'proven': 1,
#  'legal': 1,
#  'noticeable': 1,
#  'force': 1,
#  'except': 1,
#  'known': 1,
#  'meal': 1,
#  'chicken': 1,
#  'grow': 1,
#  'normal': 1,
#  'cow': 1,
#  'milk': 1,
#  'hormone': 1,
#  'nation': 1,
#  'transport': 1,
#  'store': 1,
#  'kept': 1,
#  'complete': 1,
#  'waste': 1,
#  'expensive': 1,
#  'deadline': 1,
#  'twice': 1,
#  'lucky': 1,
#  'heat': 1,
#  'alcohol': 1,
#  'corona': 1,
#  'cur': 1,
#  'mark': 1,
#  'beast': 1,
#  'member': 1,
#  'amnesty': 1,
#  'controversy': 1,
#  'consume': 1,
#  'duress': 1,
#  'school': 1,
#  'impossible': 1,
#  'headache': 1,
#  'coerce': 1,
#  'region': 1,
#  'average': 1,
#  'age': 1,
#  'list': 1,
#  'recovery': 1,
#  'logic': 1,
#  'crisis': 2,
#  'rife': 1,
#  'murder': 1,
#  'mine': 1,
#  'prepare': 1,
#  'albino': 1,
#  'strain': 1,
#  'improve': 1,
#  'lord': 1,
#  'potatoes': 1,
#  'fat': 1,
#  'false': 1,
#  'epileptic': 1,
#  'composition': 1,
#  'nowadays': 1,
#  'asleep': 1,
#  'painful': 1,
#  'herd': 1,
#  'dumb': 1,
#  'enough': 1,
#  'mess': 1,
#  'existent': 1,
#  'grown': 1,
#  'thank': 1,
#  'fit': 1,
#  'forward': 1,
#  'service': 1,
#  'status': 1,
#  'lady': 1,
#  'comment': 1,
#  'woman': 1,
#  'abroad': 1,
#  'lying': 1,
#  'treasonous': 1,
#  'shill': 1,
#  'deception': 1,
#  'eternal': 1,
#  'buy': 1,
#  'show': 1,
#  'prosecution': 1,
#  'injury': 1,
#  'occur': 1,
#  'top': 1,
#  'contain': 1,
#  'technology': 1,
#  'course': 1,
#  'feed': 1,
#  'manure': 1,
#  'held': 1,
#  'adverse': 1,
#  'd': 1,
#  'sun': 1,
#  'zinc': 1,
#  'stuff': 1,
#  'greed': 1,
#  'oblige': 1,
#  'load': 1,
#  'bull': 1,
#  'inform': 1,
#  'public': 1,
#  'excellent': 1,
#  'mild': 1,
#  'correct': 1,
#  'amount': 1,
#  'baby': 1,
#  'tissue': 1,
#  'inside': 1,
#  'necromancy': 1,
#  'spiritual': 1,
#  'trade': 1,
#  'offer': 1,
#  'j': 2,
#  'phase': 1,
#  'process': 1,
#  'afraid': 2,
#  'donate': 1,
#  'bloody': 1,
#  'journal': 1,
#  'date': 1,
#  'instead': 1,
#  'complex': 1,
#  'bottom': 1,
#  'forget': 1,
#  'relief': 1,
#  'afford': 1,
#  'secure': 1,
#  'supply': 2,
#  'sputnik': 1,
#  'desperate': 1,
#  'indeed': 1,
#  'hole': 1,
#  'slow': 1,
#  'travel': 1,
#  'sue': 1,
#  'file': 1,
#  'lawsuit': 1,
#  'fellow': 1,
#  'rich': 1,
#  'queue': 1,
#  'term': 1,
#  'mystery': 1,
#  'juice': 1,
#  'standby': 1,
#  'unite': 1,
#  'alliance': 1,
#  'pharmacy': 1,
#  'sorry': 1,
#  'bat': 1,
#  'soup': 1,
#  'agree': 3,
#  'cos': 1,
#  'alter': 1,
#  'pop': 1,
#  'sudden': 1,
#  'hit': 1,
#  'fast': 1,
#  'mask': 1,
#  'pneumonia': 1,
#  'social': 1,
#  'odd': 1,
#  'immense': 1,
#  'corruption': 1,
#  'court': 1,
#  'incredible': 1,
#  'close': 1,
#  'survive': 1,
#  'curse': 1,
#  'absolute': 1,
#  'proxy': 1,
#  'monitor': 1,
#  'choice': 1,
#  'follow': 1,
#  'liable': 1,
#  'cripple': 1,
#  'income': 1,
#  'profit': 1,
#  'altruism': 1,
#  'receive': 1,
#  'join': 1,
#  'dollar': 2,
#  'swine': 1,
#  'multi': 1,
#  'billion': 1,
#  'cash': 1,
#  'sheep': 1,
#  'societal': 1,
#  'whatever': 1,
#  'near': 1,
#  'period': 1,
#  'edge': 1,
#  'site': 1,
#  'p': 2,
#  'y': 1,
#  'week': 1,
#  'nice': 1,
#  'plunder': 1,
#  'tax': 1,
#  'revenue': 1,
#  'clever': 1,
#  'wasting': 1,
#  'miracle': 1,
#  'magic': 1,
#  'spend': 1,
#  'born': 1,
#  'bullet': 1,
#  'lose': 2,
#  'wide': 1,
#  'march': 1,
#  'storage': 1,
#  'dry': 1,
#  'ice': 1,
#  'belong': 1,
#  ...}

# %%
 # Arranging in a descending order
comment_word_counts_sorted = sorted(full_count_comments.items(), key=lambda x: x[1], reverse=True)

# %%
comment_word_counts_sorted
# Out:
# [('politician', 5),
#  ('pcr', 5),
#  ('annoy', 5),
#  ('quot', 4),
#  ('group', 4),
#  ('7', 4),
#  ('feet', 4),
#  ('attend', 4),
#  ('hoof', 4),
#  ('chew', 4),
#  ('cud', 4),
#  ('know', 3),
#  ('39', 3),
#  ('would', 3),
#  ('dr', 3),
#  ('bacteria', 3),
#  ('my', 3),
#  ('spread', 3),
#  ('cell', 3),
#  ('sa', 3),
#  ('rate', 3),
#  ('remedi', 3),
#  ('homeless', 3),
#  ('pass', 3),
#  ('eat', 3),
#  ('men', 3),
#  ('plagu', 3),
#  ('figur', 3),
#  ('school', 3),
#  ('tribul', 3),
#  ('percept', 3),
#  ('socialist', 3),
#  ('0', 3),
#  ('da', 3),
#  ('curs', 3),
#  ('among', 3),
#  ('diagnos', 3),
#  ('carl', 3),
#  ('nerv', 3),
#  ('biospher', 3),
#  ('madagascan', 3),
#  ('emit', 3),
#  ('confirm', 3),
#  ('rise', 3),
#  ('adjuv', 3),
#  ('unclean', 3),
#  ('tsk', 3),
#  ('him', 2),
#  ('trial', 2),
#  ('they', 2),
#  ('from', 2),
#  ('it', 2),
#  ('s', 2),
#  ('differ', 2),
#  ('caus', 2),
#  ('prof', 2),
#  ('drug', 2),
#  ('sister', 2),
#  ('conduct', 2),
#  ('oxford', 2),
#  ('by', 2),
#  ('freedom', 2),
#  ('choic', 2),
#  ('imbal', 2),
#  ('make', 2),
#  ('creator', 2),
#  ('ha', 2),
#  ('die', 2),
#  ('suffer', 2),
#  ('etc', 2),
#  ('perspect', 2),
#  ('compani', 2),
#  ('mani', 2),
#  ('global', 2),
#  ('matter', 2),
#  ('type', 2),
#  ('famili', 2),
#  ('coolaid', 2),
#  ('black', 2),
#  ('immun', 2),
#  ('advoc', 2),
#  ('bill', 2),
#  ('argument', 2),
#  ('mention', 2),
#  ('option', 2),
#  ('littl', 2),
#  ('johnson', 2),
#  ('off', 2),
#  ('n', 2),
#  ('toy', 2),
#  ('social', 2),
#  ('charg', 2),
#  ('list', 2),
#  ('yall', 2),
#  ('mask', 2),
#  ('per', 2),
#  ('chimp', 2),
#  ('bot', 2),
#  ('measl', 2),
#  ('statu', 2),
#  ('herd', 2),
#  ('economi', 2),
#  ('child', 2),
#  ('christian', 2),
#  ('bc', 2),
#  ('she', 2),
#  ('import', 2),
#  ('nono', 2),
#  ('immedi', 2),
#  ('technolog', 2),
#  ('bought', 2),
#  ('yk', 2),
#  ('zuma', 2),
#  ('scam', 2),
#  ('altern', 2),
#  ('increas', 2),
#  ('tb', 2),
#  ('law', 2),
#  ('meh', 2),
#  ('99', 2),
#  ('lethal', 2),
#  ('enslav', 2),
#  ('decreas', 2),
#  ('adulthood', 2),
#  ('convinc', 2),
#  ('gimmick', 2),
#  ('flaw', 2),
#  ('libya', 2),
#  ('standard', 2),
#  ('anim', 2),
#  ('wef', 2),
#  ('confer', 2),
#  ('highli', 2),
#  ('featur', 2),
#  ('tower', 2),
#  ('respect', 2),
#  ('vector', 2),
#  ('fishi', 2),
#  ('59', 2),
#  ('cancer', 2),
#  ('finish', 2),
#  ('dismiss', 2),
#  ('insan', 2),
#  ('function', 2),
#  ('mankind', 2),
#  ('militari', 2),
#  ('vanuatu', 2),
#  ('australian', 2),
#  ('employe', 2),
#  ('involv', 2),
#  ('revis', 2),
#  ('downward', 2),
#  ('deceit', 2),
#  ('forev', 2),
#  ('weed', 2),
#  ('perfect', 2),
#  ('initi', 2),
#  ('ayo', 2),
#  ('azt', 2),
#  ('emb', 2),
#  ('bibl', 2),
#  ('herb', 2),
#  ('chart', 2),
#  ('assess', 2),
#  ('jackson', 2),
#  ('null', 2),
#  ('financi', 2),
#  ('thsi', 2),
#  ('occur', 2),
#  ('bow', 2),
#  ('dat', 2),
#  ('paul', 2),
#  ('karin', 2),
#  ('q', 2),
#  ('vaxx', 2),
#  ('thru', 2),
#  ('tonsil', 2),
#  ('elect', 2),
#  ('known', 2),
#  ('org', 2),
#  ('wealthi', 2),
#  ('cognit', 2),
#  ('basher', 2),
#  ('idc', 2),
#  ('watt', 2),
#  ('misconcept', 2),
#  ('shade', 2),
#  ('scoff', 2),
#  ('whichev', 2),
#  ('passport', 2),
#  ('largest', 2),
#  ('superior', 2),
#  ('unregul', 2),
#  ('lest', 2),
#  ('mikovitz', 2),
#  ('written', 2),
#  ('boost', 2),
#  ('blog', 2),
#  ('madagasca', 2),
#  ('hay', 2),
#  ('cobalt', 2),
#  ('b12', 2),
#  ('viewpoint', 2),
#  ('metabol', 2),
#  ('valuabl', 2),
#  ('hurri', 2),
#  ('sotho', 2),
#  ('inflammatori', 2),
#  ('scholar', 2),
#  ('sheak', 2),
#  ('quo', 2),
#  ('incom', 2),
#  ('hong', 2),
#  ('kong', 2),
#  ('densiti', 2),
#  ('avg', 2),
#  ('squar', 2),
#  ('km', 2),
#  ('slow', 2),
#  ('alzheim', 2),
#  ('doc', 2),
#  ('refug', 2),
#  ('penalti', 2),
#  ('anecdot', 2),
#  ('falsifi', 2),
#  ('unfalsifi', 2),
#  ('teapot', 2),
#  ('scar', 2),
#  ('perfectli', 2),
#  ('rebel', 2),
#  ('ramaphosa', 1),
#  ('is', 1),
#  ('not', 1),
#  ('a', 1),
#  ('stupid', 1),
#  ('he', 1),
#  ('whst', 1),
#  ('best', 1),
#  ('for', 1),
#  ('the', 1),
#  ('same', 1),
#  ('take', 1),
#  ('place', 1),
#  ('in', 1),
#  ('uk', 1),
#  ('and', 1),
#  ('us', 1),
#  ('you', 1),
#  ('re', 1),
#  ('talk', 1),
#  ('rubbish', 1),
#  ('dian', 1),
#  ('wieseat', 1),
#  ('least', 1),
#  ('i', 1),
#  ('am', 1),
#  ('garbag', 1),
#  ('becaus', 1),
#  ('cannot', 1),
#  ('say', 1),
#  ('certainti', 1),
#  ('what', 1),
#  ('are', 1),
#  ('inject', 1),
#  ('to', 1),
#  ('those', 1),
#  ('south', 1),
#  ('african', 1),
#  ('wies', 1),
#  ('certain', 1),
#  ('of', 1),
#  ('vaccin', 1),
#  ('be', 1),
#  ('qualiti', 1),
#  ('quantiti', 1),
#  ('concentr', 1),
#  ('product', 1),
#  ('materi', 1),
#  ('mroots1', 1),
#  ('how', 1),
#  ('hell', 1),
#  ('all', 1),
#  ('voluntari', 1),
#  ('no', 1),
#  ('one', 1),
#  ('forc', 1),
#  ('or', 1),
#  ('coerc', 1),
#  ('into', 1),
#  ('volunt', 1),
#  ('some', 1),
#  ('peopl', 1),
#  ('will', 1),
#  ('out', 1),
#  ('good', 1),
#  ('their', 1),
#  ('heart', 1),
#  ('trust', 1),
#  ('trail', 1),
#  ('oversea', 1),
#  ('kind', 1),
#  ('problem', 1),
#  ('down', 1),
#  ('road', 1),
#  ('agre', 1),
#  ('start', 1),
#  ('with', 1),
#  ('maadi', 1),
#  ('hi', 1),
#  ('bra', 1),
#  ('abdroool', 1),
#  ('gangster', 1),
#  ('greedi', 1),
#  ('knive', 1),
#  ('crook', 1),
#  ('have', 1),
#  ('them', 1),
#  ('do', 1),
#  ('if', 1),
#  ('that', 1),
#  ('but', 1),
#  ('case', 1),
#  ('test', 1),
#  ('did', 1),
#  ('we', 1),
#  ('get', 1),
#  ('med', 1),
#  ('world', 1),
#  ('selfless', 1),
#  ('realiti', 1),
#  ('somali', 1),
#  ('right', 1),
#  ('congratul', 1),
#  ('africa', 1),
#  ('especi', 1),
#  ('first', 1),
#  ('covid', 1),
#  ('19', 1),
#  ('vax', 1),
#  ('although', 1),
#  ('prefer', 1),
#  ('independ', 1),
#  ('local', 1),
#  ('run', 1),
#  ('research', 1),
#  ('nevertheless', 1),
#  ('ok', 1),
#  ('should', 1),
#  ('thi', 1),
#  ('stay', 1),
#  ('long', 1),
#  ('haul', 1),
#  ('even', 1),
#  ('most', 1),
#  ('who', 1),
#  ('recov', 1),
#  ('last', 1),
#  ('physic', 1),
#  ('psycholog', 1),
#  ('damag', 1),
#  ('so', 1),
#  ('prevent', 1),
#  ('way', 1),
#  ('better', 1),
#  ('than', 1),
#  ('cure', 1),
#  ('let', 1),
#  ('alon', 1),
#  ('ignor', 1),
#  ('conspiraci', 1),
#  ('theori', 1),
#  ('about', 1),
#  ('bullshit', 1),
#  ('ani', 1),
#  ('doctor', 1),
#  ('accept', 1),
#  ('http', 1),
#  ('youtu', 1),
#  ('ftqhepw', 1),
#  ('rg', 1),
#  ('look', 1),
#  ('easteregg', 1),
#  ('can', 1),
#  ('find', 1),
#  ('ban', 1),
#  ('lung', 1),
#  ('tissu', 1),
#  ('video', 1),
#  ('straight', 1),
#  ('fund', 1),
#  ('gate', 1),
#  ('foundat', 1),
#  ('use', 1),
#  ('famou', 1),
#  ('as', 1),
#  ('whi', 1),
#  ('pandem', 1),
#  ('real', 1),
#  ('liter', 1),
#  ('nobodi', 1),
#  ('anyon', 1),
#  ('against', 1),
#  ('brother', 1),
#  ('on', 1),
#  ('themselv', 1),
#  ('theyr', 1),
#  ('nanotechnolog', 1),
#  ('alter', 1),
#  ('our', 1),
#  ('genet', 1),
#  ('steveninth', 1),
#  ('search', 1),
#  ('thank', 1),
#  ('info', 1),
#  ('up', 1),
#  ('point', 1),
#  ('except', 1),
#  ('where', 1),
#  ('there', 1),
#  ('an', 1),
#  ('natur', 1),
#  ('never', 1),
#  ('mistak', 1),
#  ('which', 1),
#  ('mean', 1),
#  ('caucian', 1),
#  ('white', 1),
#  ('expir', 1),
#  ('time', 1),
#  ('planet', 1),
#  ('slowli', 1),
#  ('reduc', 1),
#  ('govern', 1),
#  ('been', 1),
#  ('work', 1),
#  ('overtim', 1),
#  ('encourag', 1),
#  ('women', 1),
#  ('more', 1),
#  ('children', 1),
#  ('help', 1),
#  ('fertil', 1),
#  ('treatment', 1),
#  ('fact', 1),
#  ('pay', 1),
#  ('live', 1),
#  ('europ', 1),
#  ('go', 1),
#  ('manqoba', 1),
#  ('mkhwanazi', 1),
#  ('control', 1),
#  ('media', 1),
#  ('strike', 1),
#  ('fear', 1),
#  ('corona', 1),
#  ('viru', 1),
#  ('fake', 1),
#  ('enforc', 1),
#  ('coronaviru', 1),
#  ('isnt', 1),
#  ('mylifematt', 1),
#  ('vuj6qg7oxhw', 1),
#  ('watch', 1),
#  ('these', 1),
#  ('channel', 1),
#  ('dreami', 1),
#  ('mad', 1),
#  ('wtf', 1),
#  ('dude', 1),
#  ('u', 1),
#  ('serious', 1),
#  ('uneduc', 1),
#  ('nurs', 1),
#  ('usa', 1),
#  ('cri', 1),
#  ('whom', 1),
#  ('got', 1),
#  ('here', 1),
#  ('actor', 1),
#  ('too', 1),
#  ('employ', 1),
#  ('entir', 1),
#  ('act', 1),
#  ('movi', 1),
#  ('rf', 1),
#  ('chip', 1),
#  ('fuck', 1),
#  ('sake', 1),
#  ('think', 1),
#  ('want', 1),
#  ('tomonitor', 1),
#  ('rashid', 1),
#  ('shit', 1),
#  ('whole', 1),
#  ('new', 1),
#  ('level', 1),
#  ('put', 1),
#  ('thing', 1),
#  ('bodi', 1),
#  ('made', 1),
#  ('million', 1),
#  ('upon', 1),
#  ('virus', 1),
#  ('harm', 1),
#  ('scientif', 1),
#  ('model', 1),
#  ('germ', 1),
#  ('hoax', 1),
#  ('power', 1),
#  ('pharma', 1),
#  ('own', 1),
#  ('process', 1),
#  ('mass', 1),
#  ('now', 1),
#  ('abl', 1),
#  ('mafia', 1),
#  ('conglomer', 1),
#  ('popul', 1),
#  ('much', 1),
#  ('logic', 1),
#  ('goe', 1),
#  ('window', 1),
#  ('devil', 1),
#  ('accord', 1),
#  ('websit', 1),
#  ('consid', 1),
#  ('risk', 1),
#  ('contag', 1),
#  ('lie', 1),
#  ('afrika', 1),
#  ('alreadi', 1),
#  ('itself', 1),
#  ('without', 1),
#  ('realis', 1),
#  ('fantast', 1),
#  ('machin', 1),
#  ('psychopath', 1),
#  ('believ', 1),
#  ('surviv', 1),
#  ('ancestor', 1),
#  ('year', 1),
#  ('adapt', 1),
#  ('climat', 1),
#  ('inherit', 1),
#  ('dna', 1),
#  ('deal', 1),
#  ('certainli', 1),
#  ('enemi', 1),
#  ('idiot', 1),
#  ('continu', 1),
#  ('play', 1),
#  ('mind', 1),
#  ('game', 1),
#  ('surpris', 1),
#  ('shiva', 1),
#  ('buttar', 1),
#  ('kaufmann', 1),
#  ('kumaran', 1),
#  ('govend', 1),
#  ('correct', 1),
#  ('yo', 1),
#  ('care', 1),
#  ('appreci', 1),
#  ('bravoooooooooooooo', 1),
#  ('smart', 1),
#  ('onli', 1),
#  ('fight', 1),
#  ('evil', 1),
#  ('sometim', 1),
#  ('hate', 1),
#  ('violenc', 1),
#  ('self', 1),
#  ('defens', 1),
#  ('me', 1),
#  ('readi', 1),
#  ('face', 1),
#  ('demon', 1),
#  ('worker', 1),
#  ('wrath', 1),
#  ('man', 1),
#  ('doe', 1),
#  ('produc', 1),
#  ('righteous', 1),
#  ('god', 1),
#  ('away', 1),
#  ('gun', 1),
#  ('dankiee', 1),
#  ('malema', 1),
#  ('warn', 1),
#  ('cyril', 1),
#  ('love', 1),
#  ('money', 1),
#  ('over', 1),
#  ('see', 1),
#  ('edgar', 1),
#  ('papa', 1),
#  ('maduna', 1),
#  ('just', 1),
#  ('sit', 1),
#  ('back', 1),
#  ('yu', 1),
#  ('histori', 1),
#  ('understand', 1),
#  ('regul', 1),
#  ('western', 1),
#  ('uneth', 1),
#  ('practic', 1),
#  ('clearli', 1),
#  ('develop', 1),
#  ('countri', 1),
#  ('like', 1),
#  ('were', 1),
#  ('lace', 1),
#  ('hhcg', 1),
#  ('signific', 1),
#  ('number', 1),
#  ('ever', 1),
#  ('ye', 1),
#  ('other', 1),
#  ('insidi', 1),
#  ('carri', 1),
#  ('across', 1),
#  ('don', 1),
#  ('t', 1),
#  ('need', 1),
#  ('hard', 1),
#  ('inform', 1),
#  ('stop', 1),
#  ('drink', 1),
#  ('quit', 1),
#  ('imagin', 1),
#  ('racism', 1),
#  ('everi', 1),
#  ('event', 1),
#  ('agenda', 1),
#  ('west', 1),
#  ('killer', 1),
#  ('arriv', 1),
#  ('africawhi', 1),
#  ('unbeliev', 1),
#  ('ass', 1),
#  ('check', 1),
#  ('your', 1),
#  ('post', 1),
#  ('despic', 1),
#  ('sheepl', 1),
#  ('lead', 1),
#  ('slaughter', 1),
#  ('through', 1),
#  ('life', 1),
#  ('scare', 1),
#  ('label', 1),
#  ('probabl', 1),
#  ('couldn', 1),
#  ('less', 1),
#  ('scienc', 1),
#  ('public', 1),
#  ('refer', 1),
#  ('person', 1),
#  ('call', 1),
#  ('jesu', 1),
#  ('doesn', 1),
#  ('walk', 1),
#  ('water', 1),
#  ('nor', 1),
#  ('name', 1),
#  ('dusti', 1),
#  ('old', 1),
#  ('book', 1),
#  ('left', 1),
#  ('rule', 1),
#  ('unfortun', 1),
#  ('ve', 1),
#  ('blame', 1),
#  ('when', 1),
#  ('kick', 1),
#  ('institut', 1),
#  ('repent', 1),
#  ('invit', 1),
#  ('nation', 1),
#  ('rid', 1),
#  ('allow', 1),
#  ('still', 1),
#  ('k', 1),
#  ('lhen', 1),
#  ('went', 1),
#  ('acknowledg', 1),
#  ('seek', 1),
#  ('ancient', 1),
#  ('spiritu', 1),
#  ('instead', 1),
#  ('fed', 1),
#  ('ounc', 1),
#  ('human', 1),
#  ('creat', 1),
#  ('destroy', 1),
#  ('indigen', 1),
#  ('claim', 1),
#  ('testament', 1),
#  ('commit', 1),
#  ('hintw', 1),
#  ('sold', 1),
#  ('odwa', 1),
#  ('ngqavu', 1),
#  ('order', 1),
#  ('someth', 1),
#  ('adrea', 1),
#  ('ambassador', 1),
#  ('carrol', 1),
#  ('her', 1),
#  ('everyon', 1),
#  ('then', 1),
#  ('infect', 1),
#  ('ebola', 1),
#  ('similar', 1),
#  ('flu', 1),
#  ('threat', 1),
#  ('isn', 1),
#  ('realli', 1),
#  ('anoth', 1),
#  ('sheep', 1),
#  ('eye', 1),
#  ('wake', 1),
#  ('china', 1),
#  ('america', 1),
#  ('well', 1),
#  ('sure', 1),
#  ('doubt', 1),
#  ('predomin', 1),
#  ('cool', 1),
#  ('aid', 1),
#  ('steve', 1),
#  ('floit', 1),
#  ('bet', 1),
#  ('wouldn', 1),
#  ('lol', 1),
#  ('seen', 1),
#  ('forget', 1),
#  ('scientist', 1),
#  ('done', 1),
#  ('past', 1),
#  ('tuskege', 1),
#  ('peru', 1),
#  ('central', 1),
#  ('victim', 1),
#  ('fals', 1),
#  ('hope', 1),
#  ('syphilli', 1),
#  ('silvest', 1),
#  ('hercul', 1),
#  ('strawman', 1),
#  ('happili', 1),
#  ('happen', 1),
#  ('brazil', 1),
#  ('american', 1),
#  ('half', 1),
#  ('centuri', 1),
#  ('ago', 1),
#  ('educ', 1),
#  ('step', 1),
#  ('today', 1),
#  ('wish', 1),
#  ('particip', 1),
#  ('fine', 1),
#  ('absurd', 1),
#  ('numer', 1),
#  ('origin', 1),
#  ('wa', 1),
#  ('distort', 1),
#  ('everyth', 1),
#  ('took', 1),
#  ('huge', 1),
#  ('toward', 1),
#  ('misinform', 1),
#  ('attempt', 1),
#  ('swallow', 1),
#  ('decept', 1),
#  ('someday', 1),
#  ('predominantli', 1),
#  ('each', 1),
#  ('lot', 1),
#  ('faith', 1),
#  ('luck', 1),
#  ('also', 1),
#  ('common', 1),
#  ('sens', 1),
#  ('choos', 1),
#  ('benefit', 1),
#  ('catharin', 1),
#  ('afford', 1),
#  ('question', 1),
#  ('econom', 1),
#  ('veri', 1),
#  ('oh', 1),
#  ('meant', 1),
#  ('context', 1),
#  ('hasn', 1),
#  ('month', 1),
#  ('m', 1),
#  ('won', 1),
#  ('discov', 1),
#  ('onc', 1),
#  ('give', 1),
#  ('odd', 1),
#  ('inde', 1),
#  ('small', 1),
#  ('chose', 1),
#  ('cheap', 1),
#  ('easi', 1),
#  ('koolaid', 1),
#  ('big', 1),
#  ('comment', 1),
#  ('jimmi', 1),
#  ('carr', 1),
#  ('fan', 1),
#  ('els', 1),
#  ('steril', 1),
#  ('thousand', 1),
#  ('woman', 1),
#  ('india', 1),
#  ('come', 1),
#  ('poor', 1),
#  ('illus', 1),
#  ('lab', 1),
#  ('rat', 1),
#  ('explain', 1),
#  ('50', 1),
#  ('60', 1),
#  ('purpos', 1),
#  ('around', 1),
#  ('commun', 1),
#  ('follow', 1),
#  ('iowa', 1),
#  ('girl', 1),
#  ('amp', 1),
#  ('glen', 1),
#  ('pharmaceut', 1),
#  ('court', 1),
#  ('stolen', 1),
#  ('bio', 1),
#  ('patient', 1),
#  ('befor', 1),
#  ('covid19', 1),
#  ('far', 1),
#  ('illeg', 1),
#  ('haven', 1),
#  ('attent', 1),
#  ('organ', 1),
#  ('sell', 1),
#  ('presid', 1),
#  ('snow', 1),
#  ('grass', 1),
#  ('news', 1),
#  ('smh', 1),
#  ('blk', 1),
#  ('ain', 1),
#  ('fking', 1),
#  ('guy', 1),
#  ('ona', 1),
#  ('fkup', 1),
#  ('smelli', 1),
#  ('hand', 1),
#  ('everywher', 1),
#  ('spineless', 1),
#  ('doesnt', 1),
#  ('gut', 1),
#  ('must', 1),
#  ('rememb', 1),
#  ('wast', 1),
#  ('prepar', 1),
#  ('refus', 1),
#  ('exactli', 1),
#  ('merci', 1),
#  ('grace', 1),
#  ('mg', 1),
#  ('great', 1),
#  ('servic', 1),
#  ('content', 1),
#  ('madagascar', 1),
#  ('possibl', 1),
#  ('read', 1),
#  ('stole', 1),
#  ('hotel', 1),
#  ('late', 1),
#  ('at', 1),
#  ('head', 1),
#  ('line', 1),
#  ('flow', 1),
#  ('journey', 1),
#  ('higher', 1),
#  ('80', 1),
#  ('percent', 1),
#  ('mortal', 1),
#  ('afraid', 1),
#  ('favor', 1),
#  ('bud', 1),
#  ('open', 1),
#  ('googl', 1),
#  ('browser', 1),
#  ('four', 1),
#  ('digit', 1),
#  ('three', 1),
#  ('may', 1),
#  ('after', 1),
#  ('mate', 1),
#  ('henri', 1),
#  ('david', 1),
#  ('gonna', 1),
#  ('donkey', 1),
#  ('vote', 1),
#  ('listen', 1),
#  ('remind', 1),
#  ('june', 1),
#  ('16', 1),
#  ('1976', 1),
#  ('busi', 1),
#  ('oper', 1),
#  ('soweto', 1),
#  ('kenin', 1),
#  ('stuurman', 1),
#  ('seem', 1),
#  ('truli', 1),
#  ('safeti', 1),
#  ('industri', 1),
#  ('cold', 1),
#  ('200', 1),
#  ('rhinovirus', 1),
#  ('coronavirus', 1),
#  ('magic', 1),
#  ('plane', 1),
#  ('fli', 1),
#  ('sar', 1),
#  ('vaccinem', 1),
#  ('vaccineit', 1),
#  ('15', 1),
#  ('yearshow', 1),
#  ('becom', 1),
#  ('avail', 1),
#  ('18', 1),
#  ('experi', 1),
#  ('yep', 1),
#  ('sad', 1),
#  ('dj', 1),
#  ('papzin', 1),
#  ('glad', 1),
#  ('medic', 1),
#  ('didn', 1),
#  ('attitud', 1),
#  ('polio', 1),
#  ('ravag', 1),
#  ('futur', 1),
#  ('commentari', 1),
#  ('mutat', 1),
#  ('rapidli', 1),
#  ('useless', 1),
#  ('neema', 1),
#  ('kyamba', 1),
#  ('hmm', 1),
#  ('chang', 1),
#  ('base', 1),
#  ('unknown', 1),
#  ('youtub', 1),
#  ('such', 1),
#  ('dilemma', 1),
#  ('plan', 1),
#  ('enzym', 1),
#  ('resourc', 1),
#  ('pleas', 1),
#  ('advis', 1),
#  ('9zqr4bvarj0', 1),
#  ('vmat2', 1),
#  ('gene', 1),
#  ('fool', 1),
#  ('yourself', 1),
#  ('hahaha', 1),
#  ('reach', 1),
#  ('valid', 1),
#  ('fail', 1),
#  ('miser', 1),
#  ('low', 1),
#  ('compar', 1),
#  ('period', 1),
#  ('given', 1),
#  ('race', 1),
#  ('stoop', 1),
#  ('factual', 1),
#  ('piss', 1),
#  ('shame', 1),
#  ('earth', 1),
#  ('flat', 1),
#  ('gtfo', 1),
#  ('centr', 1),
#  ('develpp', 1),
#  ('absolut', 1),
#  ('truth', 1),
#  ('ed', 1),
#  ('g', 1),
#  ('tell', 1),
#  ('said', 1),
#  ('death', 1),
#  ...]

# %%
#Going over all sentences to get word counts and create word frequencies
full_count_replies = {}
for i in range(len(reply_tokens)):
    full_count_replies.update(get_count(reply_tokens[i]))
#full_count

# %%
 # Arranging in a descending order
reply_word_counts_sorted = sorted(full_count_replies.items(), key=lambda x: x[1], reverse=True)

# %%
#reply_word_counts_sorted[0:10]

# %%
# Stemming the words
ps = PorterStemmer() 
stemmed_reply_tokens = []
for i in range(len(reply_tokens)):
    sent = []
    for j in range(len(reply_tokens[i])):
        sent.append(ps.stem(reply_tokens[i][j]))
    stemmed_reply_tokens.append(sent)
